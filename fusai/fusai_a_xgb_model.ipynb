# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from scipy.stats import mode
import csv
import matplotlib.dates
from datetime import *
from sklearn.preprocessing import *
from sklearn import ensemble
import xgboost as xgb
from sklearn import metrics
from xgboost.sklearn import XGBClassifier  
from sklearn.model_selection import GridSearchCV,cross_val_score  
import matplotlib.pylab as plt  

from sklearn.preprocessing import *
import xgboost as xgb
from sklearn import metrics
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, StratifiedKFold
from sklearn.externals import joblib

# %%
class XgbModel:
    def __init__(self, feaNames=None, params={}):
        self.feaNames = feaNames
        self.params = {
            'objective': 'binary:logistic',
            'eval_metric':'logloss',
            'silent': True,
            'eta': 0.1,
            'max_depth': 4,
            'gamma': 0.5,
            'subsample': 0.95,
            'colsample_bytree': 1,
            'min_child_weight': 8,
            'max_delta_step': 5,
            'lambda': 100,
        }
        for k,v in params.items():
            self.params[k] = v
        self.clf = None

    def train(self, X, y, train_size=1, test_size=0.1, verbose=True, num_boost_round=1000, early_stopping_rounds=3):
        X = X.astype(float)
        if train_size==1:
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
            X_train, y_train = X, y
        else:
            X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_size)
        dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=self.feaNames)
        dval = xgb.DMatrix(X_test, label=y_test, feature_names=self.feaNames)
        watchlist = [(dtrain,'train'),(dval,'val')]
        clf = xgb.train(
            self.params, dtrain, 
            num_boost_round = num_boost_round, 
            evals = watchlist, 
            early_stopping_rounds = early_stopping_rounds,
            verbose_eval=verbose
        )
        self.clf = clf

    def trainCV(self, X, y, nFold=3, verbose=True, num_boost_round=1500, early_stopping_rounds=10):
        X = X.astype(float)
        dtrain = xgb.DMatrix(X, label=y, feature_names=self.feaNames)
        cvResult = xgb.cv(
            self.params, dtrain, 
            num_boost_round = num_boost_round, 
            nfold = nFold,
            early_stopping_rounds = early_stopping_rounds,
            verbose_eval=verbose
        )
        clf = xgb.train(
            self.params, dtrain, 
            num_boost_round = cvResult.shape[0], 
        )
        self.clf = clf

    def gridSearch(self, X, y, nFold=3, verbose=1, num_boost_round=130):
        paramsGrids = {
            # 'n_estimators': [50+5*i for i in range(0,30)],
            'gamma': [0,0.01,0.05,0.1,0.5,1,5,10,50,100],
            # 'max_depth': list(range(3,10)),
            'min_child_weight': list(range(0,10)),
            'subsample': [1-0.05*i for i in range(0,8)],
            'colsample_bytree': [1-0.05*i for i in range(0,10)],
            # 'reg_alpha': [0+2*i for i in range(0,10)],
            'reg_lambda': [0+50*i for i in range(0,10)],            
            'max_delta_step': [0+1*i for i in range(0,8)],
        }
        for k,v in paramsGrids.items():
            gsearch = GridSearchCV(
                estimator = xgb.XGBClassifier(
                    max_depth = self.params['max_depth'], 
                    gamma = self.params['gamma'],
                    learning_rate = self.params['eta'],
                    max_delta_step = self.params['max_delta_step'],
                    min_child_weight = self.params['min_child_weight'],
                    subsample = self.params['subsample'],
                    colsample_bytree = self.params['colsample_bytree'],
                    silent = self.params['silent'],
                    reg_lambda = self.params['lambda'],
                    n_estimators = num_boost_round
                ),
                # param_grid = paramsGrids,
                param_grid = {k:v},
                scoring = 'neg_log_loss',
                cv = nFold,
                verbose = verbose,
                n_jobs = 4
            )
            gsearch.fit(X, y)
            print(pd.DataFrame(gsearch.cv_results_))
            print(gsearch.best_params_)
        exit()

    def predict(self, X):
        X = X.astype(float)
        return self.clf.predict(xgb.DMatrix(X, feature_names=self.feaNames))

    def getFeaScore(self, show=False):
        fscore = self.clf.get_score()
        feaNames = fscore.keys()
        scoreDf = pd.DataFrame(index=feaNames, columns=['importance'])
        for k,v in fscore.items():
            scoreDf.loc[k, 'importance'] = v
        if show:
            print(scoreDf.sort_index(by=['importance'], ascending=False))
        return scoreDf

# 划分训练集和测试集
def trainTestSplit(df, splitDate=pd.to_datetime('2018-09-23'), trainPeriod=3, testPeriod=1):
    trainDf = df[(df.context_timestamp<splitDate)&(df.context_timestamp>=splitDate-timedelta(days=trainPeriod))]
    testDf = df[(df.context_timestamp>=splitDate)&(df.context_timestamp<splitDate+timedelta(days=testPeriod))]
    return (trainDf, testDf)


# 统计预测误差
def countDeltaY(predictSeries, labelSeries, show=True, title='', subplot=None):
    deltaSeries = predictSeries - labelSeries
    if subplot!=None:
        plt.subplot(subplot[0], subplot[1], subplot[2])
    deltaSeries.plot(style='b-')
    plt.title(title)
    if show:
        plt.show()
    return deltaSeries

# 获取stacking下一层数据集
def getOof(clf, trainX, trainY, testX, nFold=5, stratify=False):
    oofTrain = np.zeros(trainX.shape[0])
    oofTest = np.zeros(testX.shape[0])
    oofTestSkf = np.zeros((testX.shape[0], nFold))
    if stratify:
        kf = StratifiedKFold(n_splits=nFold, shuffle=True)
    else:
        kf = KFold(n_splits=nFold, shuffle=True)
    for i, (trainIdx, testIdx) in enumerate(kf.split(trainX, trainY)):
        kfTrainX = trainX[trainIdx]
        kfTrainY = trainY[trainIdx]
        kfTestX = trainX[testIdx]
        clf.trainCV(kfTrainX, kfTrainY, verbose=False)
        oofTrain[testIdx] = clf.predict(kfTestX)
        oofTestSkf[:,i] = clf.predict(testX)
    oofTest[:] = oofTestSkf.mean(axis=1)
    return oofTrain, oofTest

# %%
#首先导入滑窗训练集数据进行线下数据集划分
train_df = pd.read_csv('~/kengkeng/alimama/data/fusai_a_train_df_weilai.csv')
test_df = pd.read_csv('~/kengkeng/alimama/data/fusai_a_test_df_weilai.csv')

print(train_df.info())
print(test_df.info())

train_df['is_special'] = 0
train_df['is_special'][train_df.day == 7] = 1
test_df['is_special'] = 1

print(train_df.columns.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629767 entries, 0 to 1629766
# Data columns (total 89 columns):
# instance_id                                1629767 non-null int64
# item_id                                    1629767 non-null int64
# item_brand_id                              1629767 non-null int64
# item_city_id                               1629767 non-null int64
# item_price_level                           1629767 non-null int64
# item_sales_level                           1629767 non-null int64
# item_collected_level                       1629767 non-null int64
# item_pv_level                              1629767 non-null int64
# user_id                                    1629767 non-null int64
# user_gender_id                             1629767 non-null int64
# user_age_level                             1629767 non-null int64
# user_occupation_id                         1629767 non-null int64
# user_star_level                            1629767 non-null int64
# context_id                                 1629767 non-null int64
# context_timestamp                          1629767 non-null int64
# context_page_id                            1629767 non-null int64
# shop_id                                    1629767 non-null int64
# shop_review_num_level                      1629767 non-null int64
# shop_review_positive_rate                  1629767 non-null float64
# shop_star_level                            1629767 non-null int64
# shop_score_service                         1629767 non-null float64
# shop_score_delivery                        1629767 non-null float64
# shop_score_description                     1629767 non-null float64
# is_trade                                   1629767 non-null int64
# date                                       1629767 non-null object
# weekday                                    1629767 non-null int64
# day                                        1629767 non-null int64
# hour                                       1629767 non-null int64
# match_category_proportion                  1629767 non-null float64
# match_property_proportion                  1629767 non-null float64
# predict_category_number                    1629767 non-null int64
# predict_property_number                    1629767 non-null int64
# isFirstCategoryIn                          1629767 non-null int64
# isLastCategoryIn                           1629767 non-null int64
# category_number                            1629767 non-null int64
# property_number                            1629767 non-null int64
# all_item_brand_id_click_number             1629767 non-null float64
# all_item_brand_id_buy_number               1629767 non-null float64
# history_item_brand_id_rate                 1627182 non-null float64
# history_item_brand_id_smooth_rate          1629767 non-null float64
# all_shop_id_click_number                   1629767 non-null float64
# all_shop_id_buy_number                     1629767 non-null float64
# history_shop_id_rate                       1624770 non-null float64
# history_shop_id_smooth_rate                1629767 non-null float64
# all_item_id_click_number                   1629767 non-null float64
# all_item_id_buy_number                     1629767 non-null float64
# history_item_id_rate                       1616690 non-null float64
# history_item_id_smooth_rate                1629767 non-null float64
# lastOneHour_sameItem_count                 1629767 non-null float64
# real_first_category                        1629767 non-null int64
# real_last_category                         1629767 non-null int64
# lastOneHour_sameFirstCategory_count        1629767 non-null float64
# lastOneHour_sameLastCategory_count         1629767 non-null float64
# lastOneHour_sameBrand_count                1629767 non-null float64
# lastOneHour_sameShop_count                 1629767 non-null float64
# isLastOneHour_firstClickItem               1629767 non-null int64
# userItem_lastClickDeltaTime                1629767 non-null float64
# userBrand_lastClickDeltaTime               1629767 non-null float64
# userShop_lastClickDeltaTime                1629767 non-null float64
# userFirstCategory_lastClickDeltaTime       1629767 non-null float64
# userLastCategory_lastClickDeltaTime        1629767 non-null float64
# hour_rate                                  1629767 non-null float64
# shop_item_classNumber                      552592 non-null float64
# brand_item_classNumber                     552592 non-null float64
# city_item_classNumber                      552592 non-null float64
# shop_user_classNumber                      0 non-null float64
# brand_user_classNumber                     0 non-null float64
# city_user_classNumber                      0 non-null float64
# is_later_clickSameItem                     1629767 non-null int64
# is_later_clickSameLastCategory             1629767 non-null int64
# later_clickSameItem_count                  1629767 non-null int64
# later_clickSameLastCategory_count          1629767 non-null int64
# later_clickSameItem_deltaTime              1629767 non-null float64
# later_clickSameLastCategory_deltaTime      1629767 non-null float64
# user_id_converse_smooth_rate               1629767 non-null float64
# user_id_total_number                       1629767 non-null float64
# user_id_buy_number                         1629767 non-null float64
# item_brand_id_converse_smooth_rate         1629767 non-null float64
# item_brand_id_total_number                 1629767 non-null float64
# item_brand_id_buy_number                   1629767 non-null float64
# item_id_converse_smooth_rate               1629767 non-null float64
# item_id_total_number                       1629767 non-null float64
# item_id_buy_number                         1629767 non-null float64
# shop_id_converse_smooth_rate               1629767 non-null float64
# shop_id_total_number                       1629767 non-null float64
# shop_id_buy_number                         1629767 non-null float64
# real_last_category_converse_smooth_rate    1629767 non-null float64
# real_last_category_total_number            1629767 non-null float64
# real_last_category_buy_number              1629767 non-null float64
# dtypes: float64(52), int64(36), object(1)
# memory usage: 1.1+ GB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519888 entries, 0 to 519887
# Data columns (total 88 columns):
# instance_id                                519888 non-null int64
# item_id                                    519888 non-null int64
# item_brand_id                              519888 non-null int64
# item_city_id                               519888 non-null int64
# item_price_level                           519888 non-null int64
# item_sales_level                           519888 non-null int64
# item_collected_level                       519888 non-null int64
# item_pv_level                              519888 non-null int64
# user_id                                    519888 non-null int64
# user_gender_id                             519888 non-null int64
# user_age_level                             519888 non-null int64
# user_occupation_id                         519888 non-null int64
# user_star_level                            519888 non-null int64
# context_id                                 519888 non-null int64
# context_timestamp                          519888 non-null int64
# context_page_id                            519888 non-null int64
# shop_id                                    519888 non-null int64
# shop_review_num_level                      519888 non-null int64
# shop_review_positive_rate                  519888 non-null float64
# shop_star_level                            519888 non-null int64
# shop_score_service                         519888 non-null float64
# shop_score_delivery                        519888 non-null float64
# shop_score_description                     519888 non-null float64
# date                                       519888 non-null object
# weekday                                    519888 non-null int64
# day                                        519888 non-null int64
# hour                                       519888 non-null int64
# match_category_proportion                  519888 non-null float64
# match_property_proportion                  519888 non-null float64
# predict_category_number                    519888 non-null int64
# predict_property_number                    519888 non-null int64
# isFirstCategoryIn                          519888 non-null int64
# isLastCategoryIn                           519888 non-null int64
# category_number                            519888 non-null int64
# property_number                            519888 non-null int64
# all_item_brand_id_click_number             519888 non-null float64
# all_item_brand_id_buy_number               519888 non-null float64
# history_item_brand_id_rate                 518950 non-null float64
# history_item_brand_id_smooth_rate          519888 non-null float64
# all_shop_id_click_number                   519888 non-null float64
# all_shop_id_buy_number                     519888 non-null float64
# history_shop_id_rate                       518316 non-null float64
# history_shop_id_smooth_rate                519888 non-null float64
# all_item_id_click_number                   519888 non-null float64
# all_item_id_buy_number                     519888 non-null float64
# history_item_id_rate                       514824 non-null float64
# history_item_id_smooth_rate                519888 non-null float64
# lastOneHour_sameItem_count                 519888 non-null float64
# real_first_category                        519888 non-null int64
# real_last_category                         519888 non-null int64
# lastOneHour_sameFirstCategory_count        519888 non-null float64
# lastOneHour_sameLastCategory_count         519888 non-null float64
# lastOneHour_sameBrand_count                519888 non-null float64
# lastOneHour_sameShop_count                 519888 non-null float64
# isLastOneHour_firstClickItem               519888 non-null int64
# userItem_lastClickDeltaTime                519888 non-null float64
# userBrand_lastClickDeltaTime               519888 non-null float64
# userShop_lastClickDeltaTime                519888 non-null float64
# userFirstCategory_lastClickDeltaTime       519888 non-null float64
# userLastCategory_lastClickDeltaTime        519888 non-null float64
# hour_rate                                  519888 non-null float64
# shop_item_classNumber                      0 non-null float64
# brand_item_classNumber                     0 non-null float64
# city_item_classNumber                      0 non-null float64
# shop_user_classNumber                      0 non-null float64
# brand_user_classNumber                     0 non-null float64
# city_user_classNumber                      0 non-null float64
# is_later_clickSameItem                     519888 non-null int64
# is_later_clickSameLastCategory             519888 non-null int64
# later_clickSameItem_count                  519888 non-null int64
# later_clickSameLastCategory_count          519888 non-null int64
# later_clickSameItem_deltaTime              519888 non-null float64
# later_clickSameLastCategory_deltaTime      519888 non-null float64
# user_id_converse_smooth_rate               519888 non-null float64
# user_id_total_number                       519888 non-null float64
# user_id_buy_number                         519888 non-null float64
# item_brand_id_converse_smooth_rate         519888 non-null float64
# item_brand_id_total_number                 519888 non-null float64
# item_brand_id_buy_number                   519888 non-null float64
# item_id_converse_smooth_rate               519888 non-null float64
# item_id_total_number                       519888 non-null float64
# item_id_buy_number                         519888 non-null float64
# shop_id_converse_smooth_rate               519888 non-null float64
# shop_id_total_number                       519888 non-null float64
# shop_id_buy_number                         519888 non-null float64
# real_last_category_converse_smooth_rate    519888 non-null float64
# real_last_category_total_number            519888 non-null float64
# real_last_category_buy_number              519888 non-null float64
# dtypes: float64(52), int64(35), object(1)
# memory usage: 349.0+ MB
# None
# ['instance_id' 'item_id' 'item_brand_id' 'item_city_id' 'item_price_level'
#  'item_sales_level' 'item_collected_level' 'item_pv_level' 'user_id'
#  'user_gender_id' 'user_age_level' 'user_occupation_id' 'user_star_level'
#  'context_id' 'context_timestamp' 'context_page_id' 'shop_id'
#  'shop_review_num_level' 'shop_review_positive_rate' 'shop_star_level'
#  'shop_score_service' 'shop_score_delivery' 'shop_score_description'
#  'is_trade' 'date' 'weekday' 'day' 'hour' 'match_category_proportion'
#  'match_property_proportion' 'predict_category_number'
#  'predict_property_number' 'isFirstCategoryIn' 'isLastCategoryIn'
#  'category_number' 'property_number' 'all_item_brand_id_click_number'
#  'all_item_brand_id_buy_number' 'history_item_brand_id_rate'
#  'history_item_brand_id_smooth_rate' 'all_shop_id_click_number'
#  'all_shop_id_buy_number' 'history_shop_id_rate'
#  'history_shop_id_smooth_rate' 'all_item_id_click_number'
#  'all_item_id_buy_number' 'history_item_id_rate'
#  'history_item_id_smooth_rate' 'lastOneHour_sameItem_count'
#  'real_first_category' 'real_last_category'
#  'lastOneHour_sameFirstCategory_count' 'lastOneHour_sameLastCategory_count'
#  'lastOneHour_sameBrand_count' 'lastOneHour_sameShop_count'
#  'isLastOneHour_firstClickItem' 'userItem_lastClickDeltaTime'
#  'userBrand_lastClickDeltaTime' 'userShop_lastClickDeltaTime'
#  'userFirstCategory_lastClickDeltaTime'
#  'userLastCategory_lastClickDeltaTime' 'hour_rate' 'shop_item_classNumber'
#  'brand_item_classNumber' 'city_item_classNumber' 'shop_user_classNumber'
#  'brand_user_classNumber' 'city_user_classNumber' 'is_later_clickSameItem'
#  'is_later_clickSameLastCategory' 'later_clickSameItem_count'
#  'later_clickSameLastCategory_count' 'later_clickSameItem_deltaTime'
#  'later_clickSameLastCategory_deltaTime' 'user_id_converse_smooth_rate'
#  'user_id_total_number' 'user_id_buy_number'
#  'item_brand_id_converse_smooth_rate' 'item_brand_id_total_number'
#  'item_brand_id_buy_number' 'item_id_converse_smooth_rate'
#  'item_id_total_number' 'item_id_buy_number' 'shop_id_converse_smooth_rate'
#  'shop_id_total_number' 'shop_id_buy_number'
#  'real_last_category_converse_smooth_rate'
#  'real_last_category_total_number' 'real_last_category_buy_number'
#  'is_special']
# /home/lab-zhao.yinhu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
fea = [
       
     'item_brand_id', 'item_city_id', 'item_price_level', 'item_sales_level',
     'item_collected_level', 'item_pv_level', 'user_gender_id',
     'user_age_level', 'user_occupation_id', 'user_star_level',
     'context_page_id', 
     'shop_review_num_level', 'shop_review_positive_rate',
     'shop_star_level', 'shop_score_service', 'shop_score_delivery',
     'shop_score_description',
     'match_category_proportion', 'match_property_proportion', 'predict_category_number',
     'predict_property_number', 'isFirstCategoryIn', 'isLastCategoryIn',
     'category_number', 'property_number',
     'all_item_brand_id_click_number',
     'all_item_brand_id_buy_number',
     'history_item_brand_id_smooth_rate', 'all_shop_id_click_number',
     'all_shop_id_buy_number',
     'history_shop_id_smooth_rate', 'all_item_id_click_number',
     'all_item_id_buy_number',
     'history_item_id_smooth_rate', 'lastOneHour_sameItem_count',
     'lastOneHour_sameFirstCategory_count', 'lastOneHour_sameLastCategory_count',
     'lastOneHour_sameBrand_count', 'lastOneHour_sameShop_count',
     'isLastOneHour_firstClickItem',
     'is_special', 'hour',
     'userItem_lastClickDeltaTime',
     'userBrand_lastClickDeltaTime', 'userShop_lastClickDeltaTime',
     'userFirstCategory_lastClickDeltaTime',
     'userLastCategory_lastClickDeltaTime', 'hour_rate', 
     'user_id_converse_smooth_rate', 'user_id_total_number', 'user_id_buy_number',
     'item_brand_id_converse_smooth_rate', 'item_brand_id_total_number',
     'item_brand_id_buy_number', 'item_id_converse_smooth_rate',
     'item_id_total_number', 'item_id_buy_number', 'shop_id_converse_smooth_rate',
     'shop_id_total_number', 'shop_id_buy_number',
     'real_last_category_converse_smooth_rate',
     'real_last_category_total_number', 'real_last_category_buy_number',
     'is_later_clickSameItem', 'is_later_clickSameLastCategory', 
     'later_clickSameItem_count', 'later_clickSameLastCategory_count',
     'later_clickSameItem_deltaTime', 'later_clickSameLastCategory_deltaTime',
#      'shop_item_classNumber', 'brand_item_classNumber', 'city_item_classNumber',
#      'shop_user_classNumber', 'brand_user_classNumber', 'city_user_classNumber'
    
      ]

# %%
xgbModel = XgbModel(feaNames=fea)
modelName = "xgb_fusai_a"

# 正式模型
startTime = datetime.now()
xgbModel.trainCV(train_df[fea].values, train_df['is_trade'].values)
xgbModel.getFeaScore(show=True)
print('training time: ', datetime.now()-startTime)
# Out:
# [0]	train-logloss:0.61071+2.73537e-05	test-logloss:0.610713+1.93276e-05
# [1]	train-logloss:0.543257+6.45824e-05	test-logloss:0.543262+2.34141e-05
# [2]	train-logloss:0.487194+8.92051e-05	test-logloss:0.487204+3.49698e-05
# [3]	train-logloss:0.440031+9.09078e-05	test-logloss:0.440044+6.88686e-05
# [4]	train-logloss:0.399977+0.000107757	test-logloss:0.399995+8.36341e-05
# [5]	train-logloss:0.365739+0.000118136	test-logloss:0.365761+0.000104337
# [6]	train-logloss:0.336301+0.000124328	test-logloss:0.336327+0.000129869
# [7]	train-logloss:0.310881+0.000137494	test-logloss:0.310912+0.000141989
# [8]	train-logloss:0.288845+0.000147901	test-logloss:0.288882+0.000159162
# [9]	train-logloss:0.269686+0.000155401	test-logloss:0.269723+0.000176954
# [10]	train-logloss:0.253+0.000165	test-logloss:0.253041+0.000194622
# [11]	train-logloss:0.238431+0.00017134	test-logloss:0.238474+0.000213433
# [12]	train-logloss:0.225697+0.000178405	test-logloss:0.225742+0.000231301
# [13]	train-logloss:0.214551+0.000183773	test-logloss:0.214598+0.000244726
# [14]	train-logloss:0.20479+0.000188413	test-logloss:0.204843+0.000259081
# [15]	train-logloss:0.196238+0.000195902	test-logloss:0.196294+0.000273675
# [16]	train-logloss:0.188738+0.000199206	test-logloss:0.188799+0.000286029
# [17]	train-logloss:0.182153+0.000204168	test-logloss:0.18222+0.000299447
# [18]	train-logloss:0.176389+0.000209323	test-logloss:0.17646+0.00030483
# [19]	train-logloss:0.171328+0.000212401	test-logloss:0.171404+0.000322083
# [20]	train-logloss:0.166894+0.000213771	test-logloss:0.166977+0.000340226
# [21]	train-logloss:0.163001+0.000217122	test-logloss:0.163089+0.000345223
# [22]	train-logloss:0.159588+0.000221134	test-logloss:0.159681+0.000360016
# [23]	train-logloss:0.1566+0.000227031	test-logloss:0.156698+0.000364582
# [24]	train-logloss:0.153974+0.000230759	test-logloss:0.154077+0.000377431
# [25]	train-logloss:0.151672+0.000234392	test-logloss:0.151781+0.000387619
# [26]	train-logloss:0.149651+0.000235538	test-logloss:0.149765+0.000396818
# [27]	train-logloss:0.147878+0.00023971	test-logloss:0.147998+0.000399485
# [28]	train-logloss:0.146324+0.000241629	test-logloss:0.146448+0.000408882
# [29]	train-logloss:0.144954+0.000242672	test-logloss:0.145086+0.000413248
# [30]	train-logloss:0.143752+0.000247792	test-logloss:0.14389+0.000418723
# [31]	train-logloss:0.142696+0.000250674	test-logloss:0.142842+0.000421205
# [32]	train-logloss:0.141767+0.000253903	test-logloss:0.141918+0.000428408
# [33]	train-logloss:0.140939+0.00025649	test-logloss:0.141095+0.000429628
# [34]	train-logloss:0.140216+0.000257295	test-logloss:0.140376+0.000441008
# [35]	train-logloss:0.139561+0.0002584	test-logloss:0.139728+0.000441485
# [36]	train-logloss:0.138985+0.00026736	test-logloss:0.139157+0.00043997
# [37]	train-logloss:0.138478+0.000277245	test-logloss:0.138656+0.000435661
# [38]	train-logloss:0.138029+0.000276063	test-logloss:0.138211+0.000440952
# [39]	train-logloss:0.137617+0.000274906	test-logloss:0.137807+0.00044776
# [40]	train-logloss:0.137246+0.000271225	test-logloss:0.137445+0.000454932
# [41]	train-logloss:0.136916+0.000275178	test-logloss:0.137118+0.0004604
# [42]	train-logloss:0.136624+0.00028766	test-logloss:0.136831+0.000451501
# [43]	train-logloss:0.136359+0.000277686	test-logloss:0.136573+0.000462309
# [44]	train-logloss:0.136122+0.000274122	test-logloss:0.136345+0.000470194
# [45]	train-logloss:0.135906+0.000265738	test-logloss:0.136133+0.000486203
# [46]	train-logloss:0.135703+0.000269514	test-logloss:0.13594+0.000482916
# [47]	train-logloss:0.135513+0.000261652	test-logloss:0.135761+0.000493667
# [48]	train-logloss:0.135345+0.000274022	test-logloss:0.135597+0.000489146
# [49]	train-logloss:0.135184+0.000263016	test-logloss:0.135442+0.000505025
# [50]	train-logloss:0.135039+0.000270558	test-logloss:0.135308+0.000498673
# [51]	train-logloss:0.134912+0.000272632	test-logloss:0.135184+0.000501561
# [52]	train-logloss:0.134794+0.000275725	test-logloss:0.135069+0.000500694
# [53]	train-logloss:0.134666+0.000274265	test-logloss:0.134953+0.000506818
# [54]	train-logloss:0.13456+0.000275237	test-logloss:0.134852+0.000508064
# [55]	train-logloss:0.134465+0.000275943	test-logloss:0.134764+0.000506494
# [56]	train-logloss:0.134375+0.000279041	test-logloss:0.13468+0.000503307
# [57]	train-logloss:0.134288+0.000281163	test-logloss:0.134602+0.000501486
# [58]	train-logloss:0.13419+0.000272216	test-logloss:0.134517+0.000511218
# [59]	train-logloss:0.134115+0.000266088	test-logloss:0.134445+0.000519354
# [60]	train-logloss:0.134027+0.000279719	test-logloss:0.134364+0.000504151
# [61]	train-logloss:0.133961+0.000278755	test-logloss:0.134306+0.000502623
# [62]	train-logloss:0.133893+0.000279242	test-logloss:0.134244+0.000502796
# [63]	train-logloss:0.133839+0.000280144	test-logloss:0.134194+0.000505716
# [64]	train-logloss:0.133772+0.000271873	test-logloss:0.134134+0.00051233
# [65]	train-logloss:0.133708+0.000277652	test-logloss:0.13408+0.000506383
# [66]	train-logloss:0.133642+0.000258914	test-logloss:0.134022+0.000524927
# [67]	train-logloss:0.133588+0.000255908	test-logloss:0.133977+0.000528694
# [68]	train-logloss:0.133528+0.000254685	test-logloss:0.133921+0.000533114
# [69]	train-logloss:0.133481+0.000255896	test-logloss:0.133882+0.000533919
# [70]	train-logloss:0.133434+0.000256727	test-logloss:0.133844+0.000531272
# [71]	train-logloss:0.133386+0.000251674	test-logloss:0.1338+0.000536427
# [72]	train-logloss:0.133331+0.000259305	test-logloss:0.133752+0.000533007
# [73]	train-logloss:0.133292+0.000258752	test-logloss:0.133722+0.000532489
# [74]	train-logloss:0.133251+0.000260815	test-logloss:0.13369+0.000531915
# [75]	train-logloss:0.133214+0.000261061	test-logloss:0.133659+0.000531666
# [76]	train-logloss:0.133166+0.000253517	test-logloss:0.133617+0.000538358
# [77]	train-logloss:0.133127+0.000257258	test-logloss:0.133586+0.000535417
# [78]	train-logloss:0.133085+0.000264206	test-logloss:0.133548+0.000529715
# [79]	train-logloss:0.133036+0.000273971	test-logloss:0.133503+0.000519913
# [80]	train-logloss:0.133002+0.000272869	test-logloss:0.133477+0.000519468
# [81]	train-logloss:0.132966+0.000276059	test-logloss:0.133448+0.000518997
# [82]	train-logloss:0.132935+0.000276616	test-logloss:0.133422+0.000520769
# [83]	train-logloss:0.132895+0.000270778	test-logloss:0.133388+0.000524912
# [84]	train-logloss:0.132864+0.000268188	test-logloss:0.133365+0.00052624
# [85]	train-logloss:0.132836+0.00026823	test-logloss:0.13334+0.000527778
# [86]	train-logloss:0.132801+0.000264656	test-logloss:0.133316+0.00052966
# [87]	train-logloss:0.132773+0.000260258	test-logloss:0.133294+0.000534487
# [88]	train-logloss:0.13274+0.000262375	test-logloss:0.133268+0.000530886
# [89]	train-logloss:0.132705+0.000260149	test-logloss:0.13324+0.00053106
# [90]	train-logloss:0.132668+0.000272429	test-logloss:0.133208+0.000518861
# [91]	train-logloss:0.132632+0.000274601	test-logloss:0.133181+0.000520552
# [92]	train-logloss:0.132609+0.000275955	test-logloss:0.133166+0.00051607
# [93]	train-logloss:0.132583+0.000279901	test-logloss:0.133145+0.000514715
# [94]	train-logloss:0.132549+0.000290166	test-logloss:0.133117+0.000503328
# [95]	train-logloss:0.132515+0.000290692	test-logloss:0.133092+0.000502926
# [96]	train-logloss:0.13249+0.000291493	test-logloss:0.133073+0.000503347
# [97]	train-logloss:0.132462+0.000289807	test-logloss:0.133052+0.000506436
# [98]	train-logloss:0.132438+0.000289456	test-logloss:0.133036+0.000506955
# [99]	train-logloss:0.132411+0.000283317	test-logloss:0.133015+0.000512221
# [100]	train-logloss:0.132382+0.000284047	test-logloss:0.132993+0.000510506
# [101]	train-logloss:0.132366+0.000283056	test-logloss:0.13298+0.000512039
# [102]	train-logloss:0.132337+0.000283642	test-logloss:0.13296+0.000514059
# [103]	train-logloss:0.132313+0.000289078	test-logloss:0.132941+0.000511848
# [104]	train-logloss:0.13228+0.000283945	test-logloss:0.132915+0.000516132
# [105]	train-logloss:0.132257+0.000287502	test-logloss:0.132898+0.000512174
# [106]	train-logloss:0.132234+0.000290141	test-logloss:0.132879+0.000513382
# [107]	train-logloss:0.132211+0.000288056	test-logloss:0.132864+0.00051458
# [108]	train-logloss:0.132191+0.000288851	test-logloss:0.132853+0.000513966
# [109]	train-logloss:0.132172+0.0002859	test-logloss:0.132839+0.000514843
# [110]	train-logloss:0.132145+0.000281297	test-logloss:0.132819+0.000518666
# [111]	train-logloss:0.132125+0.000282618	test-logloss:0.132803+0.000516624
# [112]	train-logloss:0.132111+0.000284274	test-logloss:0.132794+0.0005176
# [113]	train-logloss:0.132091+0.000285156	test-logloss:0.13278+0.00052127
# [114]	train-logloss:0.132065+0.000293769	test-logloss:0.132762+0.000511722
# [115]	train-logloss:0.132044+0.000294058	test-logloss:0.132749+0.000512266
# [116]	train-logloss:0.132028+0.000293391	test-logloss:0.132736+0.000512648
# [117]	train-logloss:0.132002+0.000292671	test-logloss:0.132715+0.000514044
# [118]	train-logloss:0.131984+0.00029039	test-logloss:0.132703+0.000515564
# [119]	train-logloss:0.131965+0.000289927	test-logloss:0.132689+0.000517243
# [120]	train-logloss:0.131945+0.000292233	test-logloss:0.132672+0.000513142
# [121]	train-logloss:0.131928+0.000292858	test-logloss:0.13266+0.000512086
# [122]	train-logloss:0.131913+0.000295527	test-logloss:0.132651+0.000508365
# [123]	train-logloss:0.131894+0.0003013	test-logloss:0.132639+0.000505613
# [124]	train-logloss:0.131877+0.000299262	test-logloss:0.132625+0.00050766
# [125]	train-logloss:0.131854+0.000296327	test-logloss:0.132609+0.000510537
# [126]	train-logloss:0.131837+0.000294513	test-logloss:0.132597+0.000510038
# [127]	train-logloss:0.131824+0.000294053	test-logloss:0.132589+0.000510506
# [128]	train-logloss:0.1318+0.000293071	test-logloss:0.132573+0.00051136
# [129]	train-logloss:0.131786+0.000293983	test-logloss:0.132563+0.000513327
# [130]	train-logloss:0.131773+0.000293855	test-logloss:0.132556+0.000511809
# [131]	train-logloss:0.131761+0.000293559	test-logloss:0.132548+0.000511805
# [132]	train-logloss:0.131744+0.000296294	test-logloss:0.132537+0.000511449
# [133]	train-logloss:0.131725+0.000297139	test-logloss:0.132524+0.000510038
# [134]	train-logloss:0.131709+0.000296318	test-logloss:0.132514+0.000511944
# [135]	train-logloss:0.131695+0.000298028	test-logloss:0.132506+0.000511378
# [136]	train-logloss:0.131679+0.00030096	test-logloss:0.132495+0.000507755
# [137]	train-logloss:0.131665+0.000295185	test-logloss:0.132485+0.000512296
# [138]	train-logloss:0.131653+0.000295301	test-logloss:0.132478+0.000512839
# [139]	train-logloss:0.131644+0.000296109	test-logloss:0.132472+0.00051399
# [140]	train-logloss:0.131627+0.000298945	test-logloss:0.132462+0.000512812
# [141]	train-logloss:0.131615+0.000300084	test-logloss:0.132453+0.000512296
# [142]	train-logloss:0.131601+0.000296658	test-logloss:0.132442+0.000514751
# [143]	train-logloss:0.131588+0.000296447	test-logloss:0.132433+0.000515992
# [144]	train-logloss:0.131577+0.00029463	test-logloss:0.132425+0.000516708
# [145]	train-logloss:0.131562+0.000297794	test-logloss:0.132418+0.000514751
# [146]	train-logloss:0.131548+0.000299237	test-logloss:0.132409+0.000513854
# [147]	train-logloss:0.131532+0.00029132	test-logloss:0.132398+0.000519378
# [148]	train-logloss:0.13152+0.000292737	test-logloss:0.132391+0.000518041
# [149]	train-logloss:0.131508+0.000292616	test-logloss:0.132383+0.000516528
# [150]	train-logloss:0.131495+0.00029302	test-logloss:0.132375+0.000517329
# [151]	train-logloss:0.131485+0.000295347	test-logloss:0.13237+0.000516528
# [152]	train-logloss:0.131476+0.000295202	test-logloss:0.132364+0.000517075
# [153]	train-logloss:0.131465+0.000297714	test-logloss:0.132358+0.000515998
# [154]	train-logloss:0.131448+0.000300149	test-logloss:0.132348+0.000515281
# [155]	train-logloss:0.131435+0.000297711	test-logloss:0.132342+0.000514656
# [156]	train-logloss:0.131421+0.000302024	test-logloss:0.132333+0.000511093
# [157]	train-logloss:0.131409+0.000300654	test-logloss:0.132325+0.00051243
# [158]	train-logloss:0.131399+0.000300325	test-logloss:0.132319+0.000513322
# [159]	train-logloss:0.131387+0.000301497	test-logloss:0.132313+0.000514656
# [160]	train-logloss:0.131375+0.000304504	test-logloss:0.132308+0.000514389
# [161]	train-logloss:0.131363+0.00030261	test-logloss:0.132301+0.000516082
# [162]	train-logloss:0.131353+0.000302153	test-logloss:0.132295+0.000516262
# [163]	train-logloss:0.131339+0.00030218	test-logloss:0.132287+0.000517521
# [164]	train-logloss:0.131323+0.000302683	test-logloss:0.132279+0.000517507
# [165]	train-logloss:0.131313+0.000304212	test-logloss:0.132273+0.00051724
# [166]	train-logloss:0.131303+0.000302478	test-logloss:0.132267+0.000516262
# [167]	train-logloss:0.131291+0.00030413	test-logloss:0.132259+0.000516711
# [168]	train-logloss:0.131283+0.000305248	test-logloss:0.132255+0.000515281
# [169]	train-logloss:0.131275+0.000305552	test-logloss:0.132251+0.000516266
# [170]	train-logloss:0.131264+0.000303338	test-logloss:0.132246+0.000519032
# [171]	train-logloss:0.131254+0.000300779	test-logloss:0.132242+0.00052054
# [172]	train-logloss:0.131241+0.000303548	test-logloss:0.132235+0.0005192
# [173]	train-logloss:0.13123+0.000303395	test-logloss:0.13223+0.000519556
# [174]	train-logloss:0.131217+0.000301829	test-logloss:0.132222+0.000521962
# [175]	train-logloss:0.131209+0.000301237	test-logloss:0.132217+0.000522496
# [176]	train-logloss:0.131196+0.000297706	test-logloss:0.13221+0.000525885
# [177]	train-logloss:0.131186+0.000298425	test-logloss:0.132203+0.000525805
# [178]	train-logloss:0.131174+0.000303196	test-logloss:0.132197+0.000522603
# [179]	train-logloss:0.131162+0.000300712	test-logloss:0.132191+0.000524672
# [180]	train-logloss:0.131149+0.000303659	test-logloss:0.132183+0.000522772
# [181]	train-logloss:0.131132+0.000299374	test-logloss:0.13217+0.000527128
# [182]	train-logloss:0.131122+0.00029648	test-logloss:0.132165+0.000527933
# [183]	train-logloss:0.131109+0.000296902	test-logloss:0.132156+0.000526014
# [184]	train-logloss:0.1311+0.000298881	test-logloss:0.132152+0.000525472
# [185]	train-logloss:0.131092+0.000299521	test-logloss:0.13215+0.000526557
# [186]	train-logloss:0.131079+0.000301146	test-logloss:0.132142+0.000526719
# [187]	train-logloss:0.131067+0.000301534	test-logloss:0.132136+0.000526437
# [188]	train-logloss:0.131059+0.000299523	test-logloss:0.132133+0.000527872
# [189]	train-logloss:0.131048+0.000298275	test-logloss:0.132128+0.000530108
# [190]	train-logloss:0.131039+0.000296725	test-logloss:0.132125+0.000530908
# [191]	train-logloss:0.131026+0.000296439	test-logloss:0.13212+0.000530746
# [192]	train-logloss:0.131014+0.000295502	test-logloss:0.132114+0.000530272
# [193]	train-logloss:0.131006+0.000295031	test-logloss:0.13211+0.000529732
# [194]	train-logloss:0.130999+0.00029504	test-logloss:0.132106+0.000531426
# [195]	train-logloss:0.130987+0.000294719	test-logloss:0.132098+0.000533013
# [196]	train-logloss:0.13098+0.000297192	test-logloss:0.132095+0.000530783
# [197]	train-logloss:0.130964+0.000294874	test-logloss:0.132088+0.000532922
# [198]	train-logloss:0.130952+0.000298273	test-logloss:0.132081+0.000531675
# [199]	train-logloss:0.130944+0.00029565	test-logloss:0.132078+0.00053203
# [200]	train-logloss:0.130935+0.000294723	test-logloss:0.132076+0.000532742
# [201]	train-logloss:0.130924+0.000293836	test-logloss:0.132071+0.000535061
# [202]	train-logloss:0.130914+0.000294489	test-logloss:0.132067+0.000535604
# [203]	train-logloss:0.130906+0.0002943	test-logloss:0.132064+0.000534802
# [204]	train-logloss:0.130897+0.000295513	test-logloss:0.13206+0.000533999
# [205]	train-logloss:0.130885+0.000296925	test-logloss:0.132055+0.000534461
# [206]	train-logloss:0.130876+0.000297578	test-logloss:0.13205+0.000535013
# [207]	train-logloss:0.130867+0.00029753	test-logloss:0.132045+0.000534186
# [208]	train-logloss:0.130859+0.000295555	test-logloss:0.132041+0.000535624
# [209]	train-logloss:0.13085+0.000298138	test-logloss:0.132037+0.000532495
# [210]	train-logloss:0.130843+0.000297355	test-logloss:0.132034+0.000532035
# [211]	train-logloss:0.130834+0.000299658	test-logloss:0.13203+0.000530605
# [212]	train-logloss:0.130825+0.000300443	test-logloss:0.132026+0.000529283
# [213]	train-logloss:0.130817+0.000299994	test-logloss:0.132023+0.000531418
# [214]	train-logloss:0.130807+0.000298602	test-logloss:0.13202+0.000531591
# [215]	train-logloss:0.130795+0.000299874	test-logloss:0.132013+0.000532221
# [216]	train-logloss:0.130788+0.00030185	test-logloss:0.132011+0.000531146
# [217]	train-logloss:0.130776+0.000299874	test-logloss:0.132006+0.000533282
# [218]	train-logloss:0.130767+0.000302603	test-logloss:0.132002+0.000530781
# [219]	train-logloss:0.130759+0.000303067	test-logloss:0.132+0.000530693
# [220]	train-logloss:0.130752+0.000301066	test-logloss:0.131996+0.000531852
# [221]	train-logloss:0.130744+0.00030153	test-logloss:0.131993+0.000531583
# [222]	train-logloss:0.130735+0.00030074	test-logloss:0.13199+0.000529979
# [223]	train-logloss:0.130726+0.000300892	test-logloss:0.131986+0.000527578
# [224]	train-logloss:0.13072+0.000298579	test-logloss:0.131982+0.000529271
# [225]	train-logloss:0.130704+0.000300436	test-logloss:0.131971+0.00052624
# [226]	train-logloss:0.130691+0.000297497	test-logloss:0.131964+0.000528299
# [227]	train-logloss:0.130685+0.00029796	test-logloss:0.131961+0.0005291
# [228]	train-logloss:0.130676+0.000295493	test-logloss:0.131958+0.000530272
# [229]	train-logloss:0.130669+0.000297355	test-logloss:0.131957+0.000531333
# [230]	train-logloss:0.130659+0.000296428	test-logloss:0.131952+0.000530702
# [231]	train-logloss:0.130653+0.000296892	test-logloss:0.131949+0.000530347
# [232]	train-logloss:0.130645+0.000296727	test-logloss:0.131945+0.000529809
# [233]	train-logloss:0.130632+0.000294259	test-logloss:0.131938+0.00053258
# [234]	train-logloss:0.130625+0.000295494	test-logloss:0.131936+0.000531411
# [235]	train-logloss:0.130618+0.000293334	test-logloss:0.131934+0.000532567
# [236]	train-logloss:0.130608+0.000291942	test-logloss:0.131933+0.000531502
# [237]	train-logloss:0.130599+0.00029148	test-logloss:0.131928+0.000531049
# [238]	train-logloss:0.130588+0.000290709	test-logloss:0.131921+0.000532117
# [239]	train-logloss:0.130578+0.000291979	test-logloss:0.131916+0.000529986
# [240]	train-logloss:0.130567+0.000290425	test-logloss:0.131912+0.000532654
# [241]	train-logloss:0.130559+0.000286873	test-logloss:0.131908+0.000533632
# [242]	train-logloss:0.13055+0.000288775	test-logloss:0.131905+0.000533282
# [243]	train-logloss:0.130545+0.00028801	test-logloss:0.131903+0.000533369
# [244]	train-logloss:0.130536+0.000288376	test-logloss:0.1319+0.000532666
# [245]	train-logloss:0.130528+0.000287148	test-logloss:0.131897+0.000531852
# [246]	train-logloss:0.130521+0.000286646	test-logloss:0.131895+0.000531677
# [247]	train-logloss:0.130515+0.000287245	test-logloss:0.131893+0.000531949
# [248]	train-logloss:0.130507+0.000288611	test-logloss:0.13189+0.000530693
# [249]	train-logloss:0.130501+0.00029105	test-logloss:0.131886+0.000529001
# [250]	train-logloss:0.130494+0.000291657	test-logloss:0.131884+0.00052811
# [251]	train-logloss:0.130489+0.000292121	test-logloss:0.131882+0.000527753
# [252]	train-logloss:0.130483+0.00029293	test-logloss:0.131879+0.000527936
# [253]	train-logloss:0.130473+0.000292121	test-logloss:0.131876+0.000526506
# [254]	train-logloss:0.130464+0.000294416	test-logloss:0.131872+0.000524902
# [255]	train-logloss:0.130457+0.000294874	test-logloss:0.13187+0.000525436
# [256]	train-logloss:0.130449+0.000293646	test-logloss:0.131867+0.000525171
# [257]	train-logloss:0.130442+0.000293177	test-logloss:0.131864+0.00052303
# [258]	train-logloss:0.130429+0.000288241	test-logloss:0.131856+0.000529801
# [259]	train-logloss:0.130418+0.000286701	test-logloss:0.13185+0.000532652
# [260]	train-logloss:0.130411+0.000284551	test-logloss:0.131847+0.000534525
# [261]	train-logloss:0.130401+0.000280709	test-logloss:0.131844+0.000538448
# [262]	train-logloss:0.130397+0.000280544	test-logloss:0.131842+0.000538185
# [263]	train-logloss:0.130391+0.000278384	test-logloss:0.13184+0.000538277
# [264]	train-logloss:0.130383+0.000281192	test-logloss:0.131836+0.000536676
# [265]	train-logloss:0.130377+0.000279058	test-logloss:0.131832+0.00053917
# [266]	train-logloss:0.130371+0.000277073	test-logloss:0.13183+0.000540679
# [267]	train-logloss:0.130366+0.000276011	test-logloss:0.131829+0.000541572
# [268]	train-logloss:0.13036+0.00027587	test-logloss:0.131826+0.000541218
# [269]	train-logloss:0.130351+0.000277043	test-logloss:0.131823+0.000542819
# [270]	train-logloss:0.130339+0.000278371	test-logloss:0.131816+0.000542729
# [271]	train-logloss:0.130332+0.000278846	test-logloss:0.131813+0.000542902
# [272]	train-logloss:0.130326+0.000277759	test-logloss:0.131811+0.00054326
# [273]	train-logloss:0.130321+0.000278221	test-logloss:0.13181+0.000542815
# [274]	train-logloss:0.130315+0.000278827	test-logloss:0.131808+0.000542989
# [275]	train-logloss:0.130309+0.000280069	test-logloss:0.131804+0.000542363
# [276]	train-logloss:0.130304+0.000279145	test-logloss:0.131804+0.00054272
# [277]	train-logloss:0.130295+0.000278363	test-logloss:0.131801+0.000542187
# [278]	train-logloss:0.130287+0.000281758	test-logloss:0.131797+0.0005421
# [279]	train-logloss:0.130281+0.000283147	test-logloss:0.131794+0.0005421
# [280]	train-logloss:0.130273+0.000280991	test-logloss:0.131791+0.000544237
# [281]	train-logloss:0.130267+0.00028145	test-logloss:0.13179+0.000545126
# [282]	train-logloss:0.130263+0.000281141	test-logloss:0.131789+0.000545397
# [283]	train-logloss:0.130255+0.000280082	test-logloss:0.131784+0.000545837
# [284]	train-logloss:0.130245+0.000279347	test-logloss:0.13178+0.000543701
# [285]	train-logloss:0.130239+0.000279178	test-logloss:0.131779+0.000543877
# [286]	train-logloss:0.130233+0.000279032	test-logloss:0.131777+0.000542809
# [287]	train-logloss:0.130224+0.00027794	test-logloss:0.131775+0.000542454
# [288]	train-logloss:0.130221+0.000277187	test-logloss:0.131775+0.000541918
# [289]	train-logloss:0.130209+0.000281679	test-logloss:0.131767+0.000537106
# [290]	train-logloss:0.130202+0.000279808	test-logloss:0.131763+0.000538001
# [291]	train-logloss:0.130192+0.000279233	test-logloss:0.131759+0.000538176
# [292]	train-logloss:0.130187+0.000276649	test-logloss:0.131756+0.000540491
# [293]	train-logloss:0.130181+0.000278253	test-logloss:0.131755+0.000540135
# [294]	train-logloss:0.130171+0.000281009	test-logloss:0.131752+0.00053782
# [295]	train-logloss:0.130167+0.000279449	test-logloss:0.131752+0.000537465
# [296]	train-logloss:0.130158+0.000278489	test-logloss:0.13175+0.000538357
# [297]	train-logloss:0.130151+0.000278575	test-logloss:0.131747+0.000536229
# [298]	train-logloss:0.130139+0.000278989	test-logloss:0.131742+0.000536929
# [299]	train-logloss:0.13013+0.000278684	test-logloss:0.131737+0.000534721
# [300]	train-logloss:0.130126+0.000278878	test-logloss:0.131736+0.000534814
# [301]	train-logloss:0.130119+0.000280192	test-logloss:0.131733+0.000533642
# [302]	train-logloss:0.130113+0.000280842	test-logloss:0.131732+0.000532842
# [303]	train-logloss:0.130107+0.000279988	test-logloss:0.131731+0.000532842
# [304]	train-logloss:0.130098+0.000280186	test-logloss:0.131727+0.000533567
# [305]	train-logloss:0.130089+0.000277572	test-logloss:0.131724+0.000535708
# [306]	train-logloss:0.130083+0.000275415	test-logloss:0.131721+0.000537496
# [307]	train-logloss:0.130076+0.000272957	test-logloss:0.131717+0.000537525
# [308]	train-logloss:0.130068+0.000274906	test-logloss:0.131715+0.000537238
# [309]	train-logloss:0.130064+0.000274703	test-logloss:0.131714+0.000538133
# [310]	train-logloss:0.130055+0.000274865	test-logloss:0.131713+0.000536791
# [311]	train-logloss:0.130051+0.000275531	test-logloss:0.131713+0.000537143
# [312]	train-logloss:0.130045+0.000273135	test-logloss:0.131711+0.000538133
# [313]	train-logloss:0.130037+0.000275076	test-logloss:0.13171+0.000538038
# [314]	train-logloss:0.130029+0.000274128	test-logloss:0.131707+0.000538069
# [315]	train-logloss:0.130022+0.000272992	test-logloss:0.131704+0.00053842
# [316]	train-logloss:0.130018+0.000272653	test-logloss:0.131704+0.000538868
# [317]	train-logloss:0.130013+0.00027356	test-logloss:0.131702+0.00053842
# [318]	train-logloss:0.130006+0.000272544	test-logloss:0.131699+0.00053842
# [319]	train-logloss:0.129999+0.000271521	test-logloss:0.131698+0.000538868
# [320]	train-logloss:0.129993+0.000272426	test-logloss:0.131697+0.000539123
# [321]	train-logloss:0.129986+0.000271861	test-logloss:0.131696+0.000539764
# [322]	train-logloss:0.129978+0.000274043	test-logloss:0.131693+0.000538458
# [323]	train-logloss:0.129969+0.000271871	test-logloss:0.131689+0.000542397
# [324]	train-logloss:0.129962+0.000271129	test-logloss:0.131687+0.000542595
# [325]	train-logloss:0.129953+0.000269979	test-logloss:0.131684+0.000544092
# [326]	train-logloss:0.129946+0.00027148	test-logloss:0.131683+0.000543743
# [327]	train-logloss:0.12994+0.000273784	test-logloss:0.13168+0.000541099
# [328]	train-logloss:0.129933+0.000272796	test-logloss:0.13168+0.000542595
# [329]	train-logloss:0.129926+0.000273596	test-logloss:0.131678+0.000542896
# [330]	train-logloss:0.12992+0.000274659	test-logloss:0.131678+0.000541301
# [331]	train-logloss:0.129915+0.000275552	test-logloss:0.131676+0.000540852
# [332]	train-logloss:0.129905+0.000274657	test-logloss:0.131672+0.00054036
# [333]	train-logloss:0.129898+0.0002743	test-logloss:0.13167+0.000539706
# [334]	train-logloss:0.129892+0.000275197	test-logloss:0.131668+0.000539404
# [335]	train-logloss:0.129885+0.000272632	test-logloss:0.131666+0.000539853
# [336]	train-logloss:0.129876+0.000272632	test-logloss:0.131662+0.000540912
# [337]	train-logloss:0.129872+0.000270748	test-logloss:0.131661+0.000540912
# [338]	train-logloss:0.129863+0.000269316	test-logloss:0.131661+0.000540605
# [339]	train-logloss:0.129854+0.000268961	test-logloss:0.131659+0.000542853
# [340]	train-logloss:0.129842+0.000270231	test-logloss:0.131654+0.000541205
# [341]	train-logloss:0.129837+0.000271028	test-logloss:0.131652+0.00054181
# [342]	train-logloss:0.129831+0.000269884	test-logloss:0.13165+0.000541362
# [343]	train-logloss:0.129823+0.000271099	test-logloss:0.131648+0.000540979
# [344]	train-logloss:0.129818+0.000269192	test-logloss:0.131646+0.000541618
# [345]	train-logloss:0.129812+0.000271444	test-logloss:0.131646+0.000542065
# [346]	train-logloss:0.129806+0.000271421	test-logloss:0.131643+0.000542932
# [347]	train-logloss:0.129799+0.000272776	test-logloss:0.131642+0.000543121
# [348]	train-logloss:0.129791+0.000272092	test-logloss:0.13164+0.000542674
# [349]	train-logloss:0.129785+0.000274124	test-logloss:0.131639+0.000543121
# [350]	train-logloss:0.129779+0.00027572	test-logloss:0.131638+0.000542674
# [351]	train-logloss:0.129774+0.000276163	test-logloss:0.131638+0.000543121
# [352]	train-logloss:0.129767+0.000274577	test-logloss:0.131637+0.000542674
# [353]	train-logloss:0.129757+0.000277393	test-logloss:0.13163+0.000541561
# [354]	train-logloss:0.12975+0.000276073	test-logloss:0.131629+0.000542808
# [355]	train-logloss:0.129744+0.000276812	test-logloss:0.131628+0.000543165
# [356]	train-logloss:0.129741+0.000277144	test-logloss:0.131627+0.000543165
# [357]	train-logloss:0.129736+0.00027702	test-logloss:0.131626+0.00054361
# [358]	train-logloss:0.129731+0.000277564	test-logloss:0.131626+0.000544144
# [359]	train-logloss:0.129726+0.000276442	test-logloss:0.131624+0.000543967
# [360]	train-logloss:0.129719+0.000274955	test-logloss:0.131621+0.000544769
# [361]	train-logloss:0.129714+0.00027615	test-logloss:0.13162+0.000544682
# [362]	train-logloss:0.129707+0.000275744	test-logloss:0.131619+0.000543522
# [363]	train-logloss:0.1297+0.000275076	test-logloss:0.131618+0.000544857
# [364]	train-logloss:0.129692+0.00027632	test-logloss:0.131616+0.000543075
# [365]	train-logloss:0.129684+0.000276414	test-logloss:0.131615+0.000543699
# [366]	train-logloss:0.129678+0.000275569	test-logloss:0.131613+0.000544063
# [367]	train-logloss:0.129671+0.00027441	test-logloss:0.131611+0.000545397
# [368]	train-logloss:0.129665+0.000275489	test-logloss:0.131608+0.000544079
# [369]	train-logloss:0.129657+0.000275776	test-logloss:0.131605+0.000544967
# [370]	train-logloss:0.129653+0.000275693	test-logloss:0.131604+0.000544079
# [371]	train-logloss:0.129648+0.000277231	test-logloss:0.131602+0.000543087
# [372]	train-logloss:0.129643+0.000274621	test-logloss:0.131601+0.000543087
# [373]	train-logloss:0.129639+0.00027426	test-logloss:0.131601+0.000542729
# [374]	train-logloss:0.129632+0.000274166	test-logloss:0.131598+0.000542916
# [375]	train-logloss:0.129626+0.000272346	test-logloss:0.131598+0.000543805
# [376]	train-logloss:0.129622+0.000270172	test-logloss:0.131595+0.000545755
# [377]	train-logloss:0.129618+0.000270626	test-logloss:0.131594+0.000545668
# [378]	train-logloss:0.129612+0.000269282	test-logloss:0.131592+0.000546385
# [379]	train-logloss:0.129606+0.000269523	test-logloss:0.131591+0.00054594
# [380]	train-logloss:0.129599+0.000271134	test-logloss:0.131587+0.000545241
# [381]	train-logloss:0.129592+0.000273377	test-logloss:0.131585+0.000543446
# [382]	train-logloss:0.129587+0.000273207	test-logloss:0.131584+0.000543805
# [383]	train-logloss:0.12958+0.000271231	test-logloss:0.131581+0.000545582
# [384]	train-logloss:0.129572+0.00027149	test-logloss:0.13158+0.000546932
# [385]	train-logloss:0.129565+0.000273452	test-logloss:0.131579+0.000547376
# [386]	train-logloss:0.129559+0.000273845	test-logloss:0.131577+0.000546658
# [387]	train-logloss:0.129554+0.000275159	test-logloss:0.131577+0.000547188
# [388]	train-logloss:0.129547+0.000273647	test-logloss:0.131576+0.000546658
# [389]	train-logloss:0.129542+0.000275489	test-logloss:0.131576+0.000546214
# [390]	train-logloss:0.129538+0.000275489	test-logloss:0.131575+0.000546743
# [391]	train-logloss:0.12953+0.000275415	test-logloss:0.131574+0.000546658
# [392]	train-logloss:0.129524+0.00027615	test-logloss:0.131574+0.000546829
# [393]	train-logloss:0.129521+0.000276276	test-logloss:0.131573+0.000546299
# [394]	train-logloss:0.129517+0.000276459	test-logloss:0.131572+0.000546488
# [395]	train-logloss:0.12951+0.000276402	test-logloss:0.131571+0.000546045
# [396]	train-logloss:0.129503+0.000277772	test-logloss:0.13157+0.000545685
# [397]	train-logloss:0.129497+0.000275544	test-logloss:0.131567+0.000546932
# [398]	train-logloss:0.129487+0.000275217	test-logloss:0.131563+0.000548983
# [399]	train-logloss:0.129483+0.000274173	test-logloss:0.131562+0.000549786
# [400]	train-logloss:0.129476+0.000275287	test-logloss:0.131561+0.000548095
# [401]	train-logloss:0.129471+0.000273207	test-logloss:0.131558+0.000550758
# [402]	train-logloss:0.129465+0.00027445	test-logloss:0.131557+0.000549152
# [403]	train-logloss:0.129459+0.000273387	test-logloss:0.131555+0.000549427
# [404]	train-logloss:0.129455+0.000273974	test-logloss:0.131553+0.000549342
# [405]	train-logloss:0.129449+0.000273127	test-logloss:0.131551+0.00055023
# [406]	train-logloss:0.129442+0.000272537	test-logloss:0.13155+0.000551033
# [407]	train-logloss:0.129437+0.000271559	test-logloss:0.131549+0.000549955
# [408]	train-logloss:0.12943+0.000271235	test-logloss:0.131548+0.000549978
# [409]	train-logloss:0.129425+0.000271753	test-logloss:0.131546+0.000550422
# [410]	train-logloss:0.129416+0.000270319	test-logloss:0.131545+0.000551309
# [411]	train-logloss:0.129407+0.000270911	test-logloss:0.131543+0.000551837
# [412]	train-logloss:0.129402+0.000269805	test-logloss:0.131541+0.000551753
# [413]	train-logloss:0.129395+0.000272152	test-logloss:0.131538+0.000550146
# [414]	train-logloss:0.12939+0.000269137	test-logloss:0.131536+0.000552006
# [415]	train-logloss:0.129385+0.000267764	test-logloss:0.131536+0.000551921
# [416]	train-logloss:0.129379+0.000268488	test-logloss:0.131534+0.000552176
# [417]	train-logloss:0.129374+0.000270379	test-logloss:0.131532+0.000549786
# [418]	train-logloss:0.129371+0.000270379	test-logloss:0.131531+0.000550146
# [419]	train-logloss:0.129364+0.000270248	test-logloss:0.131529+0.000549618
# [420]	train-logloss:0.12936+0.000270511	test-logloss:0.13153+0.000549175
# [421]	train-logloss:0.129355+0.000272152	test-logloss:0.131528+0.000548095
# [422]	train-logloss:0.129349+0.000273321	test-logloss:0.131527+0.000547844
# [423]	train-logloss:0.129342+0.00027319	test-logloss:0.131525+0.000547208
# [424]	train-logloss:0.129334+0.000273259	test-logloss:0.131523+0.000546932
# [425]	train-logloss:0.129328+0.000274501	test-logloss:0.131522+0.000545961
# [426]	train-logloss:0.129324+0.000275087	test-logloss:0.131521+0.000545241
# [427]	train-logloss:0.129318+0.000274694	test-logloss:0.13152+0.000544907
# [428]	train-logloss:0.129313+0.000274958	test-logloss:0.131519+0.000543743
# [429]	train-logloss:0.129308+0.000276459	test-logloss:0.131518+0.000543577
# [430]	train-logloss:0.129302+0.000276732	test-logloss:0.131517+0.000543743
# [431]	train-logloss:0.129298+0.000275159	test-logloss:0.131517+0.00054463
# [432]	train-logloss:0.129292+0.000276201	test-logloss:0.131515+0.000543635
# [433]	train-logloss:0.129286+0.000277975	test-logloss:0.131514+0.000542831
# [434]	train-logloss:0.129282+0.000279549	test-logloss:0.131513+0.000542388
# [435]	train-logloss:0.129278+0.000280999	test-logloss:0.131511+0.000541584
# [436]	train-logloss:0.129272+0.000282574	test-logloss:0.13151+0.000541396
# [437]	train-logloss:0.129266+0.000282301	test-logloss:0.131508+0.000542458
# [438]	train-logloss:0.12926+0.000280483	test-logloss:0.131506+0.000544324
# [439]	train-logloss:0.129251+0.000280353	test-logloss:0.131504+0.000545124
# [440]	train-logloss:0.129247+0.000279672	test-logloss:0.131503+0.000545391
# [441]	train-logloss:0.129241+0.00027787	test-logloss:0.131501+0.000545214
# [442]	train-logloss:0.129236+0.000278555	test-logloss:0.1315+0.000544768
# [443]	train-logloss:0.12923+0.00027572	test-logloss:0.131499+0.00054575
# [444]	train-logloss:0.129225+0.000277331	test-logloss:0.131498+0.000544775
# [445]	train-logloss:0.129221+0.00027787	test-logloss:0.131497+0.000544238
# [446]	train-logloss:0.129215+0.000276734	test-logloss:0.131498+0.000544684
# [447]	train-logloss:0.12921+0.000278555	test-logloss:0.131495+0.000543437
# [448]	train-logloss:0.129205+0.000279824	test-logloss:0.131494+0.000542281
# [449]	train-logloss:0.129198+0.000282402	test-logloss:0.131493+0.000541835
# [450]	train-logloss:0.129192+0.000282059	test-logloss:0.131491+0.000541389
# [451]	train-logloss:0.129184+0.000281717	test-logloss:0.13149+0.000541926
# [452]	train-logloss:0.129179+0.000282163	test-logloss:0.131488+0.000542373
# [453]	train-logloss:0.129173+0.000281261	test-logloss:0.131487+0.0005429
# [454]	train-logloss:0.129166+0.000279678	test-logloss:0.131486+0.000544948
# [455]	train-logloss:0.129159+0.00028228	test-logloss:0.131483+0.000542809
# [456]	train-logloss:0.129154+0.00028195	test-logloss:0.131482+0.000541297
# [457]	train-logloss:0.129148+0.000281034	test-logloss:0.131482+0.000542465
# [458]	train-logloss:0.129142+0.000280239	test-logloss:0.13148+0.000542545
# [459]	train-logloss:0.129137+0.000280923	test-logloss:0.131478+0.000542545
# [460]	train-logloss:0.12913+0.000279575	test-logloss:0.131477+0.000544057
# [461]	train-logloss:0.129124+0.000281511	test-logloss:0.131476+0.000543437
# [462]	train-logloss:0.129119+0.000279477	test-logloss:0.131475+0.000545039
# [463]	train-logloss:0.129114+0.000279299	test-logloss:0.131475+0.000544593
# [464]	train-logloss:0.129109+0.000279675	test-logloss:0.131474+0.000544948
# [465]	train-logloss:0.129104+0.000279299	test-logloss:0.131473+0.000545039
# [466]	train-logloss:0.129101+0.000279299	test-logloss:0.131473+0.000544948
# [467]	train-logloss:0.129093+0.000279963	test-logloss:0.131471+0.000543528
# [468]	train-logloss:0.129086+0.000279385	test-logloss:0.131468+0.000545145
# [469]	train-logloss:0.12908+0.000279385	test-logloss:0.131465+0.000544532
# [470]	train-logloss:0.129076+0.000277109	test-logloss:0.131464+0.00054632
# [471]	train-logloss:0.129069+0.000276513	test-logloss:0.131462+0.000546863
# [472]	train-logloss:0.129062+0.000273016	test-logloss:0.13146+0.000549995
# [473]	train-logloss:0.129057+0.000273166	test-logloss:0.131458+0.000550157
# [474]	train-logloss:0.129051+0.000272561	test-logloss:0.131457+0.000549995
# [475]	train-logloss:0.129049+0.000271534	test-logloss:0.131456+0.000550795
# [476]	train-logloss:0.129043+0.000272442	test-logloss:0.131456+0.000550252
# [477]	train-logloss:0.129038+0.000270055	test-logloss:0.131455+0.000551147
# [478]	train-logloss:0.129033+0.000268158	test-logloss:0.131455+0.000551594
# [479]	train-logloss:0.129028+0.000268646	test-logloss:0.131454+0.000550768
# [480]	train-logloss:0.129023+0.000268068	test-logloss:0.131454+0.000550768
# [481]	train-logloss:0.129018+0.000268158	test-logloss:0.131452+0.000551215
# [482]	train-logloss:0.129013+0.000269282	test-logloss:0.131453+0.000551027
# [483]	train-logloss:0.129009+0.000268827	test-logloss:0.131452+0.000551121
# [484]	train-logloss:0.129004+0.000268827	test-logloss:0.131452+0.000551027
# [485]	train-logloss:0.128999+0.000269282	test-logloss:0.13145+0.000550227
# [486]	train-logloss:0.128993+0.000270289	test-logloss:0.131449+0.00055058
# [487]	train-logloss:0.128987+0.000273016	test-logloss:0.131448+0.00055058
# [488]	train-logloss:0.128982+0.00027108	test-logloss:0.131448+0.000549427
# [489]	train-logloss:0.128977+0.000270647	test-logloss:0.131447+0.000549687
# [490]	train-logloss:0.128973+0.000270802	test-logloss:0.131446+0.000548963
# [491]	train-logloss:0.128968+0.000272045	test-logloss:0.131444+0.000548517
# [492]	train-logloss:0.128964+0.000271964	test-logloss:0.131443+0.000549948
# [493]	train-logloss:0.128958+0.000270433	test-logloss:0.131442+0.000550395
# [494]	train-logloss:0.128953+0.000267824	test-logloss:0.131442+0.000549948
# [495]	train-logloss:0.128947+0.000269402	test-logloss:0.13144+0.00054898
# [496]	train-logloss:0.128944+0.000270072	test-logloss:0.13144+0.000548626
# [497]	train-logloss:0.128939+0.000270743	test-logloss:0.13144+0.000548179
# [498]	train-logloss:0.128935+0.00026859	test-logloss:0.13144+0.000547639
# [499]	train-logloss:0.128927+0.000268947	test-logloss:0.131438+0.000546551
# [500]	train-logloss:0.128924+0.000268158	test-logloss:0.131437+0.000547352
# [501]	train-logloss:0.128918+0.000270312	test-logloss:0.131436+0.000546461
# [502]	train-logloss:0.128912+0.000270072	test-logloss:0.131434+0.000546727
# [503]	train-logloss:0.128905+0.000270072	test-logloss:0.131433+0.000547262
# [504]	train-logloss:0.1289+0.000269282	test-logloss:0.13143+0.00054842
# [505]	train-logloss:0.128895+0.000269485	test-logloss:0.13143+0.00054842
# [506]	train-logloss:0.128889+0.00027073	test-logloss:0.13143+0.000547886
# [507]	train-logloss:0.128884+0.000270862	test-logloss:0.13143+0.000549222
# [508]	train-logloss:0.128877+0.000271198	test-logloss:0.13143+0.00054842
# [509]	train-logloss:0.128873+0.000270527	test-logloss:0.131429+0.00054851
# [510]	train-logloss:0.128868+0.000270289	test-logloss:0.131428+0.000548064
# [511]	train-logloss:0.128864+0.000268136	test-logloss:0.131428+0.00054851
# [512]	train-logloss:0.128859+0.000268708	test-logloss:0.131427+0.00054851
# [513]	train-logloss:0.128853+0.000267464	test-logloss:0.131427+0.000548599
# [514]	train-logloss:0.128848+0.000269147	test-logloss:0.131425+0.000547173
# [515]	train-logloss:0.128841+0.000267902	test-logloss:0.131425+0.000548064
# [516]	train-logloss:0.128839+0.000266426	test-logloss:0.131424+0.00054851
# [517]	train-logloss:0.128834+0.000264387	test-logloss:0.131424+0.000548244
# [518]	train-logloss:0.128827+0.000266094	test-logloss:0.131422+0.000547352
# [519]	train-logloss:0.128824+0.000264739	test-logloss:0.131422+0.000546641
# [520]	train-logloss:0.128819+0.000263728	test-logloss:0.13142+0.000547443
# [521]	train-logloss:0.128815+0.000261473	test-logloss:0.13142+0.000548335
# [522]	train-logloss:0.128811+0.000263515	test-logloss:0.13142+0.000548872
# [523]	train-logloss:0.128806+0.000259912	test-logloss:0.131418+0.000549856
# [524]	train-logloss:0.128802+0.000261547	test-logloss:0.131418+0.000549764
# [525]	train-logloss:0.128799+0.000262895	test-logloss:0.131418+0.000550657
# [526]	train-logloss:0.128795+0.000262996	test-logloss:0.131417+0.000550395
# [527]	train-logloss:0.12879+0.000263446	test-logloss:0.131416+0.000549594
# [528]	train-logloss:0.128785+0.000262097	test-logloss:0.131415+0.000549594
# [529]	train-logloss:0.128781+0.000261098	test-logloss:0.131415+0.000550487
# [530]	train-logloss:0.128777+0.000262445	test-logloss:0.131415+0.000549948
# [531]	train-logloss:0.128773+0.000263941	test-logloss:0.131414+0.000550657
# [532]	train-logloss:0.128767+0.00026439	test-logloss:0.131413+0.000551103
# [533]	train-logloss:0.128763+0.00026449	test-logloss:0.131413+0.000551458
# [534]	train-logloss:0.128758+0.000264739	test-logloss:0.131413+0.000550749
# [535]	train-logloss:0.128752+0.000264641	test-logloss:0.131413+0.000550749
# [536]	train-logloss:0.128744+0.00026439	test-logloss:0.131412+0.000551103
# [537]	train-logloss:0.128738+0.000264291	test-logloss:0.13141+0.000550383
# [538]	train-logloss:0.128733+0.000262655	test-logloss:0.131409+0.00055092
# [539]	train-logloss:0.128728+0.00026176	test-logloss:0.131408+0.00055092
# [540]	train-logloss:0.128722+0.000263172	test-logloss:0.131407+0.000550293
# [541]	train-logloss:0.128718+0.000262912	test-logloss:0.131406+0.000550028
# [542]	train-logloss:0.128713+0.000261571	test-logloss:0.131404+0.000550829
# [543]	train-logloss:0.128707+0.000262725	test-logloss:0.131403+0.000550119
# [544]	train-logloss:0.1287+0.000262279	test-logloss:0.131402+0.000550565
# [545]	train-logloss:0.128694+0.000264254	test-logloss:0.131402+0.00055092
# [546]	train-logloss:0.128688+0.000265949	test-logloss:0.1314+0.000551011
# [547]	train-logloss:0.128682+0.000266301	test-logloss:0.131399+0.000551366
# [548]	train-logloss:0.128675+0.000266821	test-logloss:0.131397+0.000551812
# [549]	train-logloss:0.128671+0.000266283	test-logloss:0.131397+0.000551904
# [550]	train-logloss:0.128664+0.000266207	test-logloss:0.131396+0.000551812
# [551]	train-logloss:0.12866+0.000263619	test-logloss:0.131396+0.000552076
# [552]	train-logloss:0.128657+0.000265036	test-logloss:0.131395+0.000552522
# [553]	train-logloss:0.128651+0.000266014	test-logloss:0.131394+0.000549948
# [554]	train-logloss:0.128646+0.000268778	test-logloss:0.131393+0.000549687
# [555]	train-logloss:0.128642+0.000268435	test-logloss:0.131393+0.000549147
# [556]	train-logloss:0.128636+0.000268795	test-logloss:0.131392+0.00054924
# [557]	train-logloss:0.128631+0.000268795	test-logloss:0.131391+0.000549333
# [558]	train-logloss:0.128627+0.000271206	test-logloss:0.131391+0.00054924
# [559]	train-logloss:0.12862+0.000272177	test-logloss:0.131389+0.00054924
# [560]	train-logloss:0.128616+0.000273175	test-logloss:0.131389+0.000548886
# [561]	train-logloss:0.128612+0.000273296	test-logloss:0.131388+0.00054898
# [562]	train-logloss:0.128608+0.000273738	test-logloss:0.131388+0.000547826
# [563]	train-logloss:0.128604+0.000273013	test-logloss:0.131387+0.000547732
# [564]	train-logloss:0.128599+0.000272289	test-logloss:0.131386+0.000548086
# [565]	train-logloss:0.128593+0.00027334	test-logloss:0.131386+0.000548347
# [566]	train-logloss:0.128589+0.000273235	test-logloss:0.131385+0.000549333
# [567]	train-logloss:0.128583+0.000271988	test-logloss:0.131385+0.000551568
# [568]	train-logloss:0.128578+0.000271988	test-logloss:0.131386+0.000551568
# [569]	train-logloss:0.128573+0.000271458	test-logloss:0.131385+0.000550415
# [570]	train-logloss:0.128569+0.000271448	test-logloss:0.131384+0.000550956
# [571]	train-logloss:0.128564+0.000269579	test-logloss:0.131383+0.000550956
# [572]	train-logloss:0.128559+0.000271983	test-logloss:0.131383+0.000549995
# [573]	train-logloss:0.128555+0.000270209	test-logloss:0.131382+0.000550891
# [574]	train-logloss:0.12855+0.000269399	test-logloss:0.131381+0.000550188
# [575]	train-logloss:0.128544+0.000271538	test-logloss:0.131382+0.000551147
# [576]	train-logloss:0.128539+0.00027029	test-logloss:0.131381+0.000552394
# [577]	train-logloss:0.128533+0.000270209	test-logloss:0.131379+0.000552203
# [578]	train-logloss:0.128528+0.000270748	test-logloss:0.131377+0.000552203
# [579]	train-logloss:0.128522+0.000271102	test-logloss:0.131377+0.000551309
# [580]	train-logloss:0.128518+0.000271195	test-logloss:0.131377+0.000552109
# [581]	train-logloss:0.128513+0.000270778	test-logloss:0.131375+0.000552651
# [582]	train-logloss:0.128508+0.000271226	test-logloss:0.131374+0.000552556
# [583]	train-logloss:0.128504+0.000270876	test-logloss:0.131373+0.000553356
# [584]	train-logloss:0.128499+0.000270724	test-logloss:0.131373+0.000552721
# [585]	train-logloss:0.128493+0.000270275	test-logloss:0.131372+0.000553075
# [586]	train-logloss:0.128491+0.000270624	test-logloss:0.131372+0.000552721
# [587]	train-logloss:0.128487+0.000270129	test-logloss:0.131372+0.000553168
# [588]	train-logloss:0.128483+0.000270334	test-logloss:0.131371+0.000552815
# [589]	train-logloss:0.128478+0.00026923	test-logloss:0.13137+0.000552721
# [590]	train-logloss:0.128471+0.000269781	test-logloss:0.131369+0.000553336
# [591]	train-logloss:0.128467+0.000269578	test-logloss:0.131369+0.000553075
# [592]	train-logloss:0.128462+0.000271423	test-logloss:0.131369+0.000553075
# [593]	train-logloss:0.128455+0.000273468	test-logloss:0.131367+0.000552274
# [594]	train-logloss:0.128449+0.000274116	test-logloss:0.131367+0.000550749
# [595]	train-logloss:0.128444+0.000275263	test-logloss:0.131365+0.000549502
# [596]	train-logloss:0.12844+0.000275014	test-logloss:0.131366+0.000550041
# [597]	train-logloss:0.128436+0.000275612	test-logloss:0.131365+0.000550119
# [598]	train-logloss:0.128431+0.000274617	test-logloss:0.131364+0.000549055
# [599]	train-logloss:0.128426+0.000273468	test-logloss:0.131363+0.000548426
# [600]	train-logloss:0.128421+0.000273318	test-logloss:0.131362+0.00054869
# [601]	train-logloss:0.128416+0.000273728	test-logloss:0.131362+0.000547889
# [602]	train-logloss:0.128413+0.000272691	test-logloss:0.131362+0.000547798
# [603]	train-logloss:0.128408+0.000274282	test-logloss:0.131362+0.000547173
# [604]	train-logloss:0.128402+0.000275979	test-logloss:0.131362+0.000546817
# [605]	train-logloss:0.128397+0.000277201	test-logloss:0.131361+0.000546819
# [606]	train-logloss:0.128392+0.000276191	test-logloss:0.13136+0.000547176
# [607]	train-logloss:0.128389+0.000276567	test-logloss:0.131361+0.000547446
# [608]	train-logloss:0.128383+0.000276465	test-logloss:0.131359+0.000546915
# [609]	train-logloss:0.128379+0.000277308	test-logloss:0.131359+0.000546644
# [610]	train-logloss:0.128374+0.000277856	test-logloss:0.131358+0.000547621
# [611]	train-logloss:0.128367+0.00027716	test-logloss:0.131356+0.00054736
# [612]	train-logloss:0.128364+0.000278755	test-logloss:0.131356+0.000547089
# [613]	train-logloss:0.128358+0.000278407	test-logloss:0.131356+0.000546471
# [614]	train-logloss:0.128354+0.000279858	test-logloss:0.131356+0.000546829
# [615]	train-logloss:0.128351+0.000280451	test-logloss:0.131356+0.000547718
# [616]	train-logloss:0.128346+0.0002806	test-logloss:0.131355+0.000547804
# [617]	train-logloss:0.128342+0.000280103	test-logloss:0.131355+0.000548336
# [618]	train-logloss:0.128338+0.000280654	test-logloss:0.131355+0.000548066
# [619]	train-logloss:0.128333+0.000281762	test-logloss:0.131355+0.000548423
# [620]	train-logloss:0.128329+0.000282698	test-logloss:0.131355+0.000547709
# [621]	train-logloss:0.128325+0.000281207	test-logloss:0.131355+0.000548154
# [622]	train-logloss:0.128322+0.000279653	test-logloss:0.131355+0.000548599
# [623]	train-logloss:0.128317+0.000279614	test-logloss:0.131355+0.000548242
# [624]	train-logloss:0.128314+0.000280169	test-logloss:0.131355+0.000547352
# [625]	train-logloss:0.128306+0.000275014	test-logloss:0.131351+0.000551806
# [626]	train-logloss:0.128303+0.000275863	test-logloss:0.13135+0.000552162
# [627]	train-logloss:0.128299+0.000275163	test-logloss:0.13135+0.000552607
# [628]	train-logloss:0.128293+0.000274319	test-logloss:0.13135+0.000551005
# [629]	train-logloss:0.12829+0.000273667	test-logloss:0.13135+0.000551363
# [630]	train-logloss:0.128284+0.000274715	test-logloss:0.13135+0.000551275
# [631]	train-logloss:0.128279+0.000274565	test-logloss:0.13135+0.000551188
# [632]	train-logloss:0.128274+0.000276061	test-logloss:0.131349+0.000550657
# [633]	train-logloss:0.128268+0.000276312	test-logloss:0.131348+0.000551808
# [634]	train-logloss:0.128266+0.00027651	test-logloss:0.131348+0.000551275
# [635]	train-logloss:0.128259+0.000277711	test-logloss:0.131347+0.000551373
# [636]	train-logloss:0.128254+0.000277226	test-logloss:0.131346+0.000551015
# [637]	train-logloss:0.128251+0.000279268	test-logloss:0.131347+0.000551818
# [638]	train-logloss:0.128247+0.000278161	test-logloss:0.131346+0.000552707
# [639]	train-logloss:0.128243+0.000279305	test-logloss:0.131346+0.000552349
# [640]	train-logloss:0.128237+0.000282004	test-logloss:0.131344+0.000551459
# [641]	train-logloss:0.128232+0.000281416	test-logloss:0.131344+0.000550485
# [642]	train-logloss:0.128228+0.000279961	test-logloss:0.131342+0.000551101
# [643]	train-logloss:0.128224+0.000281698	test-logloss:0.131341+0.00054967
# [644]	train-logloss:0.12822+0.000283804	test-logloss:0.13134+0.000550115
# [645]	train-logloss:0.128215+0.000283945	test-logloss:0.13134+0.000551363
# [646]	train-logloss:0.128211+0.000284191	test-logloss:0.13134+0.000551363
# [647]	train-logloss:0.128205+0.000283354	test-logloss:0.131338+0.000551188
# [648]	train-logloss:0.128201+0.000282662	test-logloss:0.131339+0.000551275
# [649]	train-logloss:0.128198+0.000281416	test-logloss:0.131338+0.00055261
# [650]	train-logloss:0.128192+0.000282108	test-logloss:0.131337+0.000552253
# [651]	train-logloss:0.128188+0.000279755	test-logloss:0.131336+0.000552522
# [652]	train-logloss:0.128183+0.000278508	test-logloss:0.131336+0.000551633
# [653]	train-logloss:0.128179+0.000277572	test-logloss:0.131336+0.000551101
# [654]	train-logloss:0.128175+0.000277364	test-logloss:0.131336+0.000551904
# [655]	train-logloss:0.128172+0.000277017	test-logloss:0.131336+0.000552176
# [656]	train-logloss:0.128168+0.000278161	test-logloss:0.131336+0.000551818
# [657]	train-logloss:0.128163+0.000280307	test-logloss:0.131335+0.000551732
# [658]	train-logloss:0.128157+0.000280861	test-logloss:0.131335+0.000550571
# [659]	train-logloss:0.128152+0.000282558	test-logloss:0.131335+0.000550657
# [660]	train-logloss:0.128148+0.000280757	test-logloss:0.131335+0.000551904
# [661]	train-logloss:0.128144+0.000282108	test-logloss:0.131335+0.000551904
# [662]	train-logloss:0.128141+0.000282801	test-logloss:0.131335+0.000552349
# [663]	train-logloss:0.128138+0.000283394	test-logloss:0.131335+0.000552349
# [664]	train-logloss:0.128135+0.000283804	test-logloss:0.131334+0.000552262
# [665]	train-logloss:0.128132+0.000283701	test-logloss:0.131333+0.000551991
# [666]	train-logloss:0.128126+0.000284705	test-logloss:0.131333+0.000550657
# [667]	train-logloss:0.128123+0.000284255	test-logloss:0.131333+0.000551101
# [668]	train-logloss:0.128117+0.000285501	test-logloss:0.131331+0.000550657
# [669]	train-logloss:0.128112+0.000287338	test-logloss:0.131331+0.000549496
# [670]	train-logloss:0.128106+0.000286786	test-logloss:0.13133+0.000548423
# [671]	train-logloss:0.128101+0.000287338	test-logloss:0.13133+0.000547533
# [672]	train-logloss:0.128097+0.000288729	test-logloss:0.131331+0.000547002
# [673]	train-logloss:0.128094+0.00028928	test-logloss:0.131332+0.000547533
# [674]	train-logloss:0.128091+0.000289876	test-logloss:0.131332+0.000546819
# [675]	train-logloss:0.128086+0.000290077	test-logloss:0.131332+0.000547709
# [676]	train-logloss:0.128082+0.00028928	test-logloss:0.131332+0.000547797
# [677]	train-logloss:0.128076+0.000290774	test-logloss:0.131332+0.000547173
# [678]	train-logloss:0.128072+0.000290226	test-logloss:0.131332+0.000547262
# [679]	train-logloss:0.128067+0.000292571	test-logloss:0.131329+0.00054557
# [680]	train-logloss:0.128064+0.00029247	test-logloss:0.13133+0.000545659
# [681]	train-logloss:0.128059+0.00029247	test-logloss:0.131329+0.000545659
# [682]	train-logloss:0.128055+0.000292571	test-logloss:0.131328+0.00054575
# [683]	train-logloss:0.128049+0.000292874	test-logloss:0.131328+0.00054513
# [684]	train-logloss:0.128044+0.000292874	test-logloss:0.131327+0.000545668
# [685]	train-logloss:0.128038+0.000293419	test-logloss:0.131327+0.00054584
# [686]	train-logloss:0.128034+0.000294515	test-logloss:0.131328+0.000546377
# [687]	train-logloss:0.12803+0.000293168	test-logloss:0.131328+0.000545222
# [688]	train-logloss:0.128026+0.000295313	test-logloss:0.131328+0.000544421
# [689]	train-logloss:0.128021+0.000295115	test-logloss:0.131327+0.000544605
# [690]	train-logloss:0.128015+0.000295213	test-logloss:0.131327+0.000544066
# [691]	train-logloss:0.12801+0.000294166	test-logloss:0.131327+0.000544698
# [692]	train-logloss:0.128004+0.000293419	test-logloss:0.131326+0.000545052
# [693]	train-logloss:0.127999+0.000292523	test-logloss:0.131325+0.000546392
# [694]	train-logloss:0.127995+0.000292425	test-logloss:0.131325+0.000546561
# [695]	train-logloss:0.127992+0.000292233	test-logloss:0.131325+0.000547007
# [696]	train-logloss:0.127988+0.00029153	test-logloss:0.131324+0.000547007
# [697]	train-logloss:0.127983+0.000291822	test-logloss:0.131325+0.000547007
# [698]	train-logloss:0.127974+0.000288684	test-logloss:0.13132+0.000552368
# [699]	train-logloss:0.127969+0.000289036	test-logloss:0.13132+0.000552462
# [700]	train-logloss:0.127962+0.000288684	test-logloss:0.131321+0.000553168
# [701]	train-logloss:0.127956+0.000289678	test-logloss:0.13132+0.000553356
# [702]	train-logloss:0.127953+0.00028818	test-logloss:0.13132+0.000553803
# [703]	train-logloss:0.12795+0.00028818	test-logloss:0.131319+0.00055524
# [704]	train-logloss:0.127944+0.000287932	test-logloss:0.131319+0.000555688
# [705]	train-logloss:0.12794+0.000288081	test-logloss:0.131319+0.000555336
# [706]	train-logloss:0.127936+0.000289581	test-logloss:0.131318+0.000555336
# [707]	train-logloss:0.127932+0.000289527	test-logloss:0.131317+0.000555688
# [708]	train-logloss:0.127925+0.000288236	test-logloss:0.131314+0.000558566
# [709]	train-logloss:0.127919+0.000288116	test-logloss:0.131313+0.000557864
# [710]	train-logloss:0.127912+0.000290782	test-logloss:0.131309+0.000554965
# [711]	train-logloss:0.127908+0.000290782	test-logloss:0.13131+0.000555414
# [712]	train-logloss:0.127905+0.000290782	test-logloss:0.13131+0.000555414
# [713]	train-logloss:0.1279+0.000291411	test-logloss:0.131309+0.000555468
# [714]	train-logloss:0.127896+0.00029061	test-logloss:0.13131+0.000554572
# [715]	train-logloss:0.127889+0.000292029	test-logloss:0.131308+0.000552722
# [716]	train-logloss:0.127885+0.000289711	test-logloss:0.131308+0.000552624
# [717]	train-logloss:0.127882+0.000288999	test-logloss:0.131309+0.000552722
# [718]	train-logloss:0.127877+0.000288733	test-logloss:0.131309+0.000551924
# [719]	train-logloss:0.127872+0.000289997	test-logloss:0.131309+0.000552273
# [720]	train-logloss:0.127867+0.000289387	test-logloss:0.131309+0.000551924
# [721]	train-logloss:0.127863+0.000288302	test-logloss:0.131308+0.000551772
# [722]	train-logloss:0.127858+0.000288302	test-logloss:0.131308+0.00055277
# [723]	train-logloss:0.127855+0.000289291	test-logloss:0.131308+0.000553219
# [724]	train-logloss:0.127852+0.00028981	test-logloss:0.131308+0.000553119
# [725]	train-logloss:0.127846+0.00029035	test-logloss:0.131307+0.000553917
# [726]	train-logloss:0.127841+0.000290518	test-logloss:0.131307+0.000553917
# [727]	train-logloss:0.127835+0.000289625	test-logloss:0.131306+0.000553718
# [728]	train-logloss:0.127832+0.000289444	test-logloss:0.131307+0.000553269
# [729]	train-logloss:0.127829+0.000288108	test-logloss:0.131306+0.000552821
# [730]	train-logloss:0.127824+0.000289623	test-logloss:0.131305+0.000551673
# [731]	train-logloss:0.127821+0.000287574	test-logloss:0.131304+0.000553119
# [732]	train-logloss:0.127818+0.000288116	test-logloss:0.131304+0.000553119
# [733]	train-logloss:0.127813+0.000289536	test-logloss:0.131304+0.000552321
# [734]	train-logloss:0.12781+0.000289449	test-logloss:0.131304+0.000552321
# [735]	train-logloss:0.127805+0.000288919	test-logloss:0.131303+0.00055277
# [736]	train-logloss:0.127801+0.000289004	test-logloss:0.131303+0.00055277
# [737]	train-logloss:0.127796+0.000288376	test-logloss:0.131303+0.00055277
# [738]	train-logloss:0.127791+0.000288019	test-logloss:0.131302+0.000552321
# [739]	train-logloss:0.127786+0.000286415	test-logloss:0.131302+0.000551872
# [740]	train-logloss:0.127784+0.000286327	test-logloss:0.131303+0.000552221
# [741]	train-logloss:0.12778+0.000285707	test-logloss:0.131304+0.000552022
# [742]	train-logloss:0.127776+0.000285452	test-logloss:0.131303+0.00055292
# [743]	train-logloss:0.12777+0.000285646	test-logloss:0.131302+0.000553718
# [744]	train-logloss:0.127765+0.000285368	test-logloss:0.131303+0.000554516
# [745]	train-logloss:0.127759+0.000285368	test-logloss:0.131302+0.000554965
# [746]	train-logloss:0.127756+0.000286172	test-logloss:0.131302+0.000554615
# [747]	train-logloss:0.127751+0.000285926	test-logloss:0.131302+0.000554068
# [748]	train-logloss:0.127748+0.000286129	test-logloss:0.131302+0.000553619
# [749]	train-logloss:0.127743+0.000285041	test-logloss:0.131301+0.000554221
# [750]	train-logloss:0.127739+0.000285687	test-logloss:0.131301+0.000554221
# [751]	train-logloss:0.127736+0.00028605	test-logloss:0.131302+0.000555118
# [752]	train-logloss:0.127733+0.000285766	test-logloss:0.131302+0.000555216
# [753]	train-logloss:0.127728+0.000286368	test-logloss:0.131302+0.000554669
# [754]	train-logloss:0.127722+0.000285766	test-logloss:0.131301+0.000554965
# [755]	train-logloss:0.127719+0.000284803	test-logloss:0.131302+0.000555664
# [756]	train-logloss:0.127714+0.000284573	test-logloss:0.131302+0.000555862
# [757]	train-logloss:0.127708+0.000284863	test-logloss:0.131302+0.000556463
# [758]	train-logloss:0.127704+0.000284276	test-logloss:0.131301+0.000556561
# [759]	train-logloss:0.127702+0.000284203	test-logloss:0.131301+0.000556561
# [760]	train-logloss:0.127697+0.000284203	test-logloss:0.1313+0.000557109
# [761]	train-logloss:0.127693+0.000283909	test-logloss:0.131299+0.000557808
# [762]	train-logloss:0.127689+0.000284789	test-logloss:0.131298+0.000557459
# [763]	train-logloss:0.127684+0.000285669	test-logloss:0.131298+0.000558257
# [764]	train-logloss:0.127679+0.000284497	test-logloss:0.131299+0.000558257
# [765]	train-logloss:0.127675+0.000284643	test-logloss:0.131298+0.000557558
# [766]	train-logloss:0.12767+0.000283836	test-logloss:0.131297+0.000558456
# [767]	train-logloss:0.127666+0.000283176	test-logloss:0.131297+0.000559154
# [768]	train-logloss:0.127663+0.000283909	test-logloss:0.131296+0.000559504
# [769]	train-logloss:0.127659+0.000283982	test-logloss:0.131296+0.000560008
# [770]	train-logloss:0.127656+0.000284789	test-logloss:0.131295+0.00055956
# [771]	train-logloss:0.127651+0.000283102	test-logloss:0.131295+0.000560008
# [772]	train-logloss:0.127648+0.000282079	test-logloss:0.131296+0.000559209
# [773]	train-logloss:0.127643+0.000283402	test-logloss:0.131294+0.000558257
# [774]	train-logloss:0.127638+0.000284284	test-logloss:0.131294+0.000558607
# [775]	train-logloss:0.127633+0.000283998	test-logloss:0.131293+0.000559254
# [776]	train-logloss:0.127628+0.000284077	test-logloss:0.131292+0.000559603
# [777]	train-logloss:0.127624+0.000283635	test-logloss:0.131292+0.000560052
# [778]	train-logloss:0.12762+0.000285324	test-logloss:0.131291+0.000559353
# [779]	train-logloss:0.127614+0.000282596	test-logloss:0.131289+0.0005618
# [780]	train-logloss:0.127609+0.000281063	test-logloss:0.131289+0.000561003
# [781]	train-logloss:0.127602+0.000279011	test-logloss:0.131289+0.000562148
# [782]	train-logloss:0.127596+0.000279011	test-logloss:0.131288+0.000562497
# [783]	train-logloss:0.127591+0.000279973	test-logloss:0.131289+0.000562745
# [784]	train-logloss:0.127588+0.000279973	test-logloss:0.131289+0.000562745
# [785]	train-logloss:0.127584+0.000281583	test-logloss:0.131289+0.000562396
# [786]	train-logloss:0.12758+0.000280699	test-logloss:0.131288+0.000562598
# [787]	train-logloss:0.127575+0.000279168	test-logloss:0.131288+0.000562598
# [788]	train-logloss:0.127571+0.000278689	test-logloss:0.131288+0.000563148
# [789]	train-logloss:0.127566+0.000278772	test-logloss:0.131289+0.000563047
# [790]	train-logloss:0.127562+0.00027905	test-logloss:0.131289+0.000563294
# [791]	train-logloss:0.127557+0.000279329	test-logloss:0.131288+0.000562296
#                                         importance
# history_item_id_smooth_rate                    647
# later_clickSameLastCategory_deltaTime          422
# item_id_converse_smooth_rate                   403
# item_sales_level                               371
# userFirstCategory_lastClickDeltaTime           315
# property_number                                296
# shop_score_description                         296
# hour_rate                                      285
# shop_id_converse_smooth_rate                   280
# user_star_level                                273
# item_brand_id                                  268
# shop_score_delivery                            267
# history_shop_id_smooth_rate                    264
# all_item_id_click_number                       258
# shop_score_service                             246
# userItem_lastClickDeltaTime                    237
# all_shop_id_click_number                       231
# item_id_total_number                           230
# shop_review_positive_rate                      223
# item_brand_id_converse_smooth_rate             219
# item_city_id                                   218
# history_item_brand_id_smooth_rate              197
# context_page_id                                196
# userLastCategory_lastClickDeltaTime            196
# shop_id_total_number                           191
# item_collected_level                           184
# hour                                           183
# match_property_proportion                      180
# userBrand_lastClickDeltaTime                   167
# item_brand_id_total_number                     166
# ...                                            ...
# all_shop_id_buy_number                         133
# real_last_category_converse_smooth_rate        130
# match_category_proportion                      128
# is_special                                     115
# shop_id_buy_number                             115
# all_item_brand_id_click_number                 113
# later_clickSameLastCategory_count               96
# userShop_lastClickDeltaTime                     96
# item_id_buy_number                              92
# later_clickSameItem_deltaTime                   90
# item_brand_id_buy_number                        85
# all_item_brand_id_buy_number                    83
# shop_star_level                                 76
# predict_category_number                         76
# is_later_clickSameLastCategory                  70
# user_occupation_id                              67
# user_gender_id                                  64
# item_pv_level                                   61
# lastOneHour_sameFirstCategory_count             54
# lastOneHour_sameLastCategory_count              46
# user_id_total_number                            43
# category_number                                 37
# lastOneHour_sameItem_count                      36
# isFirstCategoryIn                               36
# lastOneHour_sameShop_count                      31
# is_later_clickSameItem                          23
# user_id_buy_number                              21
# isLastCategoryIn                                19
# lastOneHour_sameBrand_count                     12
# later_clickSameItem_count                        1
#
# [66 rows x 1 columns]
# training time:  0:23:59.791045
# /home/lab-zhao.yinhu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:105: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)

# %%
# 开始预测
test_df.loc[:,'predicted_score'] = xgbModel.predict(test_df[fea].values)
print('predicting time: ', datetime.now()-startTime)
print("预测结果：\n",test_df[['instance_id','predicted_score']].head())
print('预测均值：', test_df['predicted_score'].mean())
# Out:
# predicting time:  0:24:02.682356
# 预测结果：
#         instance_id  predicted_score
# 0   93294255633855         0.050628
# 1  558322259509454         0.006850
# 2  594573634113186         0.029492
# 3  667327653735176         0.040187
# 4  697732672924394         0.027147
# 预测均值： 0.047942910343408585

# %%
# 生成stacking数据集
train_df['predicted_score'] = np.nan
test_df['predicted_score'] = np.nan
train_df.loc[:,'predicted_score'], test_df.loc[:,'predicted_score'] = getOof(xgbModel, train_df[fea].values, train_df['is_trade'].values, test_df[fea].values, stratify=True)
print('oof training time: ', datetime.now()-startTime)
xgbModel.getFeaScore(show=True)
cost = metrics.log_loss(train_df['is_trade'].values, train_df['predicted_score'].values)
print('train loss: ', cost)
# Out:
# oof training time:  2:06:51.905442
#                                         importance
# history_item_id_smooth_rate                    539
# later_clickSameLastCategory_deltaTime          382
# item_sales_level                               303
# item_id_converse_smooth_rate                   265
# shop_score_description                         242
# shop_id_converse_smooth_rate                   238
# hour_rate                                      236
# property_number                                229
# userFirstCategory_lastClickDeltaTime           221
# history_shop_id_smooth_rate                    216
# shop_score_delivery                            209
# all_item_id_click_number                       197
# item_brand_id                                  194
# shop_review_positive_rate                      194
# user_star_level                                193
# shop_score_service                             193
# item_id_total_number                           181
# item_collected_level                           171
# item_city_id                                   166
# userItem_lastClickDeltaTime                    161
# userLastCategory_lastClickDeltaTime            161
# shop_id_total_number                           159
# context_page_id                                158
# all_item_id_buy_number                         157
# all_shop_id_click_number                       156
# history_item_brand_id_smooth_rate              151
# item_brand_id_converse_smooth_rate             150
# hour                                           148
# match_property_proportion                      140
# user_age_level                                 139
# ...                                            ...
# predict_property_number                        106
# match_category_proportion                      103
# shop_review_num_level                          103
# real_last_category_converse_smooth_rate         97
# all_item_brand_id_click_number                  94
# later_clickSameItem_deltaTime                   94
# is_special                                      86
# later_clickSameLastCategory_count               84
# userShop_lastClickDeltaTime                     81
# shop_id_buy_number                              79
# item_id_buy_number                              78
# shop_star_level                                 77
# item_brand_id_buy_number                        74
# all_item_brand_id_buy_number                    72
# user_occupation_id                              69
# is_later_clickSameLastCategory                  67
# predict_category_number                         63
# item_pv_level                                   50
# user_gender_id                                  46
# user_id_total_number                            43
# lastOneHour_sameLastCategory_count              38
# lastOneHour_sameFirstCategory_count             37
# isFirstCategoryIn                               28
# lastOneHour_sameItem_count                      28
# category_number                                 26
# lastOneHour_sameShop_count                      22
# is_later_clickSameItem                          19
# user_id_buy_number                              15
# lastOneHour_sameBrand_count                      8
# isLastCategoryIn                                 6
#
# [65 rows x 1 columns]
# /home/lab-zhao.yinhu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:105: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
# train loss:  0.131245255175

# %%
print('7th train loss', metrics.log_loss(train_df.loc[train_df.is_special == 1,'is_trade'].values, train_df.loc[train_df.is_special == 1,'predicted_score'].values))
print('train predict: \n',train_df[['instance_id','predicted_score']].head())
print('train predict aver:', train_df['predicted_score'].mean())
print('7th train predict aver:', train_df.loc[train_df.is_special == 1,'predicted_score'].mean())
print('test predict: \n',test_df[['instance_id','predicted_score']].head())
print('test predict aver:', test_df['predicted_score'].mean())
# Out:
# 7th train loss 0.170825609474
# train predict:
#         instance_id  predicted_score
# 0  135318204268396         0.020234
# 1  467064713704441         0.020830
# 2  479649319359792         0.078572
# 3  535627308908402         0.058819
# 4  561801501778309         0.012778
# train predict aver: 0.034565499365660994
# 7th train predict aver: 0.04610285899991572
# test predict:
#         instance_id  predicted_score
# 0   93294255633855         0.051177
# 1  558322259509454         0.008283
# 2  594573634113186         0.026079
# 3  667327653735176         0.041750
# 4  697732672924394         0.026691
# test predict aver: 0.047779947151931464

# %%
# 导出预测结果
def exportResult(df, fileName):
    df.to_csv('~/kengkeng/alimama/result/%s.txt' % fileName, sep=' ', header=True, index=False)

exportResult(test_df[['instance_id', 'predicted_score']], 'fusai_xgb_5_6_wen')
